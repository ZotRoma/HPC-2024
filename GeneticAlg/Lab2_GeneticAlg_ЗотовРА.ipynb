# %%
# !python --version
# !nvcc --version
# !pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# Out:
# Python 3.10.12
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# Collecting nvcc4jupyter
#   Downloading nvcc4jupyter-1.2.1-py3-none-any.whl.metadata (5.1 kB)
# Downloading nvcc4jupyter-1.2.1-py3-none-any.whl (10 kB)
# Installing collected packages: nvcc4jupyter
# Successfully installed nvcc4jupyter-1.2.1
# Detected platform "Colab". Running its setup...
# Source files will be saved in "/tmp/tmppdo1o9lu".

# %%
# %%cuda
# // версия 2
# // как в методичке
#
#
# #include <iostream>
# #include <vector>
# #include <algorithm>
# #include <random>
# #include <cmath>
# #include <limits>
# #include <chrono>
#
#
# const double left = -5.0; // граница слева
# const double right = 5.0; // граница справа
# const int number_points = 500; // количество точек
# const double step = (right - left)/number_points; // шаг для x
# const int POPULATION_SIZE = 2000; // Размер популяции
# const int MAX_GENERATIONS = 1000; // Максимальное количество поколений
# const double MUTATION_RATE = 0.01; // Вероятность мутации
# const double TARGET_ERROR = 1e-5; // целевая ошибка
# const int POLYNOMIAL_DEGREE = 4; // степень полинома
# std::vector<double> TARGET_POLYNOM(POLYNOMIAL_DEGREE+1);
# const double COEF_SELECTION = 0.5;
# const int maxConstIter = 50;
#
#
# std::vector<double> POINTS;
# std::vector<double> FUNCTION_VALUES;
#
# std::random_device rd;
# std::mt19937 gen(rd());
# std::uniform_real_distribution<> dis(left, right);
# std::uniform_real_distribution<> distr(-1.0, 1.0);
#
# // Тип для хранения коэффициентов полинома
# using Individual = std::vector<double>;
#
# // Подсчёт значения полинома в точке x для данных коэффициентов
# double function_value(const Individual& individual, double x) {
#     double result = 0.0;
#     for (int i = 0; i <= POLYNOMIAL_DEGREE; ++i) { result += individual[i] * std::pow(x, i); }
#     return result;
# }
#
# void initFuncValues(){
#     for(double& value: TARGET_POLYNOM) value = dis(gen);
#     for(double point = left; point < right; point+= step){
#         POINTS.push_back(point);
#         FUNCTION_VALUES.push_back(function_value(TARGET_POLYNOM,point));
#     }
# }
#
# // Функция оценки пригодности (fitness) для каждого индивидуума, в целом не используется, так как использую сортировку, и просто там используется функция подсчета ошибки
# std::vector<double> Fitness(const std::vector<Individual>& population) {
#     std::vector<double> fitnesses(population.size());
#     for (int i = 0; i < population.size(); ++i) {
#         double sumError = 0.0;
#         for (int j = 0; j < POINTS.size(); ++j) {
#             double f_approx = function_value(population[i], POINTS[j]);
#             sumError += std::pow(FUNCTION_VALUES[j] - f_approx, 2);
#         }
#         fitnesses[i] = sumError / POINTS.size();
#     }
#     return fitnesses;
# }
#
# // Скрещивание (crossover) двух родителей для создания двух детей
# std::vector<Individual> Crossover(std::vector<Individual> population){
#     std::vector<Individual> newPopulation;
#     // на первом шаге, делаем скрещивание 1 элемента с любым, чтобы не потерять лучшего индивида
#     while(newPopulation.size()<POPULATION_SIZE&&population.size()>0){
#         int parent1ID;
#         if(newPopulation.size() == 0) parent1ID = 0;
#         else parent1ID = gen()%population.size();
#         int parent2ID = gen()%population.size();
#         if(parent2ID==parent1ID){
#             if(parent2ID>0) parent2ID--;
#             else parent2ID++;
#         }
#         Individual parent1 = population[parent1ID];
#         Individual parent2 = population[parent2ID];
#
#         population.erase(population.begin() + std::max(parent1ID, parent2ID));
#         population.erase(population.begin() + std::min(parent1ID, parent2ID));
#         Individual child1(POLYNOMIAL_DEGREE+1);
#         Individual child2(POLYNOMIAL_DEGREE+1);
#
#         int crosspoint = 1 + gen() % (POLYNOMIAL_DEGREE - 1);
#         for(int i = 0; i<crosspoint; i++){
#             child1[i] = parent1[i];
#             child2[i] = parent2[i];
#         }
#         for(int i = crosspoint; i<=POLYNOMIAL_DEGREE; i++){
#             child1[i] = parent2[i];
#             child2[i] = parent1[i];
#         }
#         newPopulation.push_back(parent1);
#         newPopulation.push_back(parent2);
#         newPopulation.push_back(child1);
#         newPopulation.push_back(child2);
#     }
#     return newPopulation;
# }
#
#
#
# // Мутация
# void Mutation(std::vector<Individual>& population) {
#     std::uniform_int_distribution<> dist(0, POLYNOMIAL_DEGREE);
#     for (size_t i = 1; i < population.size(); ++i) {
#         Individual& individual = population[i];
#
#         if (distr(gen) < MUTATION_RATE) {
#             int mutNum = 1 + dist(gen) % 2; // мутируем 1 или 2 гена
#             for (int j = 0; j < mutNum; ++j) {
#                 int bit_to_mutate = dist(gen);  // выбираем случайный ген
#                 individual[bit_to_mutate] += distr(gen); // добавляем случайное значение
#             }
#         }
#     }
# }
#
# double fitn(const Individual& individual){
#     double error = 0.0;
#     for(int i = 0; i<POINTS.size(); i++){
#         double aprox = function_value(individual, POINTS[i]);
#         error += std::pow(FUNCTION_VALUES[i]-aprox,2);
#     }
#     return error/POINTS.size();
# }
#
# // Отбор лучших индивидов
# std::vector<Individual> Selection(std::vector<Individual> population){
#     std::sort(population.begin(),population.end(), [](const Individual& a, const Individual& b){return fitn(a)<fitn(b);});
#     return std::vector<Individual>(population.begin(), population.begin() + population.size()*COEF_SELECTION);
# }
#
#
# std::vector<Individual> initPopulation(){
#     std::vector<Individual> population;
#     for(int i = 0; i < POPULATION_SIZE; i++){
#         Individual individual(POLYNOMIAL_DEGREE+1);
#         for(double& ind: individual){
#             ind = dis(gen);
#         }
#         population.push_back(individual);
#     }
#     return population;
# }
#
#
# // Генетический алгоритм
# Individual GeneticAlgorithm() {
#     // Инициализация начальной популяции
#     std::vector<Individual> population = initPopulation();
#
#     double bestFitness = std::numeric_limits<double>::infinity();
#     Individual bestIndividual;
#
#     int counterIter = 0;
#     for ( int generation = 0; generation < MAX_GENERATIONS;generation++) {
#         // Оценка пригодности
#         //std::vector<double> fitnesses = Fitness(population);
#
#         // Выбираем лучших особей
#         population = Selection(population);
#
#         // Скрещивание и создание нового поколения
#         population = Crossover(population);
#
#         // Применяем мутацию
#         Mutation(population);
#
#         // Определяем лучшего индивидуума в текущем поколении
#         Individual currentIndividual = population[0];
#         double currentFitness = fitn(currentIndividual);
#
#         if (currentFitness < bestFitness) {
#             counterIter = 0;
#             bestFitness = currentFitness;
#             bestIndividual = currentIndividual;
#         }
#
#         std::cout << "Поколение CPU " << generation << ", Лучшая точность: " << bestFitness << std::endl;
#         if(bestFitness < TARGET_ERROR) break;
#         counterIter++;
#         if(counterIter==maxConstIter) return bestIndividual;
#     }
#
#     return bestIndividual;
# }
#
# std::vector<Individual> SelectionForGPU(const std::vector<Individual>& population, const std::vector<double>& fitnesses) {
#     // Парные значения фитнеса и индивида
#     std::vector<std::pair<double, Individual>> fitness_individual_pairs;
#     for (int i = 0; i < population.size(); ++i) {
#         fitness_individual_pairs.emplace_back(fitnesses[i], population[i]);
#     }
#     // Сортируем по фитнесу
#     std::sort(fitness_individual_pairs.begin(), fitness_individual_pairs.end(), [](const auto& a, const auto& b) { return a.first < b.first; });
#     // Выбираем лучших
#     int num_selected = static_cast<int>(population.size() * COEF_SELECTION);
#     std::vector<Individual> selected_population;
#     for (int i = 0; i < num_selected; ++i) {
#         selected_population.push_back(fitness_individual_pairs[i].second);
#     }
#     return selected_population;
# }
# // Ядро CUDA для вычисления пригодности
# __global__ void fitnessKernel(const double* population, double* fitness_scores, const double* points, const double* function_values, int degree, int points_count) {
#     int idx = blockIdx.x * blockDim.x + threadIdx.x;
#     if (idx < POPULATION_SIZE) {
#         double error = 0.0;
#         for (int i = 0; i < points_count; ++i) {
#             double approx = 0;
#             for(int j = 0; j<=degree; j++){
#                 approx += population[idx*(degree+1)+j]*pow(points[i],j);
#             }
#             error += pow(function_values[i] - approx, 2);
#         }
#         fitness_scores[idx] = error / points_count;
#     }
# }
#
# void reverse_vector_to_array(double* h_population, std::vector<Individual> population){
#     for(int i = 0; i<population.size(); i++){
#         for(int j = 0; j<=POLYNOMIAL_DEGREE; j++){
#             h_population[i*(POLYNOMIAL_DEGREE+1)+j] = population[i][j];
#         }
#     }
# }
#
# void reverse_array_to_vector(double* h_population, std::vector<Individual>& population){
#     for(int i = 0; i<population.size(); i++){
#         for(int j = 0; j<=POLYNOMIAL_DEGREE; j++){
#             population[i][j] = h_population[i*(POLYNOMIAL_DEGREE+1)+j] ;
#         }
#     }
# }
#
# std::vector<double> evaluateFitnessOnGPU(const std::vector<Individual>& population) {
#     double* d_population;
#     double* d_fitness_scores;
#     double* d_points;
#     double* d_function_values;
#     double* h_population = new double[(POLYNOMIAL_DEGREE + 1)*POPULATION_SIZE];
#     reverse_vector_to_array(h_population,population);
#     std::vector<double> fitness_scores(POPULATION_SIZE);
#
#     int individual_size = (POLYNOMIAL_DEGREE + 1) * sizeof(double);
#     int population_size = POPULATION_SIZE * individual_size;
#
#     cudaMalloc(&d_population, population_size);
#     cudaMalloc(&d_fitness_scores, POPULATION_SIZE * sizeof(double));
#     cudaMalloc(&d_points, POINTS.size() * sizeof(double));
#     cudaMalloc(&d_function_values, FUNCTION_VALUES.size() * sizeof(double));
#
#     cudaMemcpy(d_population, h_population, population_size, cudaMemcpyHostToDevice);
#     cudaMemcpy(d_points, POINTS.data(), POINTS.size() * sizeof(double), cudaMemcpyHostToDevice);
#     cudaMemcpy(d_function_values, FUNCTION_VALUES.data(), FUNCTION_VALUES.size() * sizeof(double), cudaMemcpyHostToDevice);
#
#     int thread_in_block = 32;
#     int blocks = (POPULATION_SIZE + thread_in_block-1) / thread_in_block;
#     fitnessKernel<<<blocks, thread_in_block>>>(d_population, d_fitness_scores, d_points, d_function_values, POLYNOMIAL_DEGREE, POINTS.size());
#     cudaDeviceSynchronize();
#
#     cudaMemcpy(fitness_scores.data(), d_fitness_scores, POPULATION_SIZE * sizeof(double), cudaMemcpyDeviceToHost);
#
#     cudaFree(d_population);
#     cudaFree(d_fitness_scores);
#     cudaFree(d_points);
#     cudaFree(d_function_values);
#     delete[] h_population;
#
#     return fitness_scores;
# }
#
# Individual GeneticAlgorithmGPU() {
#     // Инициализация начальной популяции
#     std::vector<Individual> population = initPopulation();
#
#     double bestFitness = std::numeric_limits<double>::infinity();
#     Individual bestIndividual;
#
#     int counterIter = 0;
#     for ( int generation = 0; generation < MAX_GENERATIONS; generation++) {
#         // Оценка пригодности
#         std::vector<double> fitnesses = evaluateFitnessOnGPU(population);
#
#         // Выбираем лучших особей
#         population = SelectionForGPU(population, fitnesses);
#
#
#         // Скрещивание и создание нового поколения
#         population = Crossover(population);
#
#         // Применяем мутацию
#         Mutation(population);
#
#         Individual currentIndividual  = population[0];
#         double currentFitness = fitn(currentIndividual);
#         // Определяем лучшего индивидуума в текущем поколении
#
#         if (currentFitness < bestFitness) {
#             counterIter = 0;
#             bestFitness = currentFitness;
#             bestIndividual = currentIndividual;
#         }
#
#         std::cout << "Поколение GPU " << generation << ", Лучшая точность: " << bestFitness << std::endl;
#         if(bestFitness < TARGET_ERROR) break;
#         counterIter++;
#         if(counterIter==maxConstIter) return bestIndividual;
#     }
#
#     return bestIndividual;
# }
#
#
# int main() {
#     initFuncValues();
#
#     auto start_gpu = std::chrono::high_resolution_clock::now();
#     Individual best_solution_gpu = GeneticAlgorithmGPU();
#     auto end_gpu = std::chrono::high_resolution_clock::now();
#     std::chrono::duration<double> elapsed_gpu = end_gpu - start_gpu;
#
#
#     /**/
#     auto start_cpu = std::chrono::high_resolution_clock::now();
#     Individual best_solution = GeneticAlgorithm();
#     auto end_cpu = std::chrono::high_resolution_clock::now();
#     std::chrono::duration<double> elapsed_cpu = end_cpu - start_cpu;
#
#     std::cout << "Заданные коэффициенты: ";
#     for (double coeff : TARGET_POLYNOM) {
#         std::cout << coeff << " ";
#     }
#
#     std::cout << std::endl;
#     std::cout <<"Точность: "<<fitn(best_solution) << ". Время выполнения CPU: " << elapsed_cpu.count() <<  ". Лучшие коэффициенты полинома CPU: ";
#     for (double coeff : best_solution) {
#         std::cout << coeff << " ";
#     }
#     std::cout << std::endl;
#
#
#     std::cout <<"Точность: "<<fitn(best_solution_gpu)  << ". Время выполнения GPU: " << elapsed_gpu.count() << ". Лучшие коэффициенты полинома GPU: ";
#     for (double coeff : best_solution_gpu) {
#         std::cout << coeff << " ";
#     }
#     std::cout << std::endl;
#
#     return 0;
# }
# Out:
# Поколение GPU 0, Лучшая точность: 337.843
# Поколение GPU 1, Лучшая точность: 180.421
# Поколение GPU 2, Лучшая точность: 180.421
# Поколение GPU 3, Лучшая точность: 49.5171
# Поколение GPU 4, Лучшая точность: 49.5171
# Поколение GPU 5, Лучшая точность: 49.5171
# Поколение GPU 6, Лучшая точность: 41.7043
# Поколение GPU 7, Лучшая точность: 23.1146
# Поколение GPU 8, Лучшая точность: 23.1146
# Поколение GPU 9, Лучшая точность: 20.2076
# Поколение GPU 10, Лучшая точность: 20.2076
# Поколение GPU 11, Лучшая точность: 15.5165
# Поколение GPU 12, Лучшая точность: 8.45921
# Поколение GPU 13, Лучшая точность: 8.45921
# Поколение GPU 14, Лучшая точность: 8.45921
# Поколение GPU 15, Лучшая точность: 8.45921
# Поколение GPU 16, Лучшая точность: 8.45921
# Поколение GPU 17, Лучшая точность: 8.45921
# Поколение GPU 18, Лучшая точность: 3.42789
# Поколение GPU 19, Лучшая точность: 3.26632
# Поколение GPU 20, Лучшая точность: 3.26632
# Поколение GPU 21, Лучшая точность: 3.26632
# Поколение GPU 22, Лучшая точность: 3.19548
# Поколение GPU 23, Лучшая точность: 3.19548
# Поколение GPU 24, Лучшая точность: 1.92622
# Поколение GPU 25, Лучшая точность: 1.92622
# Поколение GPU 26, Лучшая точность: 1.92622
# Поколение GPU 27, Лучшая точность: 1.80156
# Поколение GPU 28, Лучшая точность: 1.80156
# Поколение GPU 29, Лучшая точность: 1.63599
# Поколение GPU 30, Лучшая точность: 1.63599
# Поколение GPU 31, Лучшая точность: 1.63599
# Поколение GPU 32, Лучшая точность: 1.63599
# Поколение GPU 33, Лучшая точность: 1.63599
# Поколение GPU 34, Лучшая точность: 1.63599
# Поколение GPU 35, Лучшая точность: 1.63599
# Поколение GPU 36, Лучшая точность: 1.63599
# Поколение GPU 37, Лучшая точность: 1.63599
# Поколение GPU 38, Лучшая точность: 1.63599
# Поколение GPU 39, Лучшая точность: 1.63599
# Поколение GPU 40, Лучшая точность: 1.63599
# Поколение GPU 41, Лучшая точность: 1.63599
# Поколение GPU 42, Лучшая точность: 1.63599
# Поколение GPU 43, Лучшая точность: 1.63599
# Поколение GPU 44, Лучшая точность: 1.63599
# Поколение GPU 45, Лучшая точность: 1.63599
# Поколение GPU 46, Лучшая точность: 1.63599
# Поколение GPU 47, Лучшая точность: 1.5268
# Поколение GPU 48, Лучшая точность: 1.5268
# Поколение GPU 49, Лучшая точность: 1.5268
# Поколение GPU 50, Лучшая точность: 1.5268
# Поколение GPU 51, Лучшая точность: 1.5268
# Поколение GPU 52, Лучшая точность: 1.5268
# Поколение GPU 53, Лучшая точность: 1.5268
# Поколение GPU 54, Лучшая точность: 1.5268
# Поколение GPU 55, Лучшая точность: 1.5268
# Поколение GPU 56, Лучшая точность: 0.858979
# Поколение GPU 57, Лучшая точность: 0.858979
# Поколение GPU 58, Лучшая точность: 0.858979
# Поколение GPU 59, Лучшая точность: 0.858979
# Поколение GPU 60, Лучшая точность: 0.858979
# Поколение GPU 61, Лучшая точность: 0.858979
# Поколение GPU 62, Лучшая точность: 0.564908
# Поколение GPU 63, Лучшая точность: 0.564908
# Поколение GPU 64, Лучшая точность: 0.564908
# Поколение GPU 65, Лучшая точность: 0.564908
# Поколение GPU 66, Лучшая точность: 0.564908
# Поколение GPU 67, Лучшая точность: 0.479552
# Поколение GPU 68, Лучшая точность: 0.479552
# Поколение GPU 69, Лучшая точность: 0.479552
# Поколение GPU 70, Лучшая точность: 0.479552
# Поколение GPU 71, Лучшая точность: 0.479552
# Поколение GPU 72, Лучшая точность: 0.479552
# Поколение GPU 73, Лучшая точность: 0.479552
# Поколение GPU 74, Лучшая точность: 0.479552
# Поколение GPU 75, Лучшая точность: 0.479552
# Поколение GPU 76, Лучшая точность: 0.479552
# Поколение GPU 77, Лучшая точность: 0.479552
# Поколение GPU 78, Лучшая точность: 0.479552
# Поколение GPU 79, Лучшая точность: 0.479552
# Поколение GPU 80, Лучшая точность: 0.479552
# Поколение GPU 81, Лучшая точность: 0.479552
# Поколение GPU 82, Лучшая точность: 0.479552
# Поколение GPU 83, Лучшая точность: 0.479552
# Поколение GPU 84, Лучшая точность: 0.440186
# Поколение GPU 85, Лучшая точность: 0.440186
# Поколение GPU 86, Лучшая точность: 0.440186
# Поколение GPU 87, Лучшая точность: 0.440186
# Поколение GPU 88, Лучшая точность: 0.440186
# Поколение GPU 89, Лучшая точность: 0.440186
# Поколение GPU 90, Лучшая точность: 0.440186
# Поколение GPU 91, Лучшая точность: 0.440186
# Поколение GPU 92, Лучшая точность: 0.440186
# Поколение GPU 93, Лучшая точность: 0.440186
# Поколение GPU 94, Лучшая точность: 0.440186
# Поколение GPU 95, Лучшая точность: 0.440186
# Поколение GPU 96, Лучшая точность: 0.440186
# Поколение GPU 97, Лучшая точность: 0.440186
# Поколение GPU 98, Лучшая точность: 0.440186
# Поколение GPU 99, Лучшая точность: 0.440186
# Поколение GPU 100, Лучшая точность: 0.440186
# Поколение GPU 101, Лучшая точность: 0.440186
# Поколение GPU 102, Лучшая точность: 0.440186
# Поколение GPU 103, Лучшая точность: 0.440186
# Поколение GPU 104, Лучшая точность: 0.440186
# Поколение GPU 105, Лучшая точность: 0.440186
# Поколение GPU 106, Лучшая точность: 0.440186
# Поколение GPU 107, Лучшая точность: 0.440186
# Поколение GPU 108, Лучшая точность: 0.440186
# Поколение GPU 109, Лучшая точность: 0.440186
# Поколение GPU 110, Лучшая точность: 0.440186
# Поколение GPU 111, Лучшая точность: 0.440186
# Поколение GPU 112, Лучшая точность: 0.440186
# Поколение GPU 113, Лучшая точность: 0.440186
# Поколение GPU 114, Лучшая точность: 0.440186
# Поколение GPU 115, Лучшая точность: 0.440186
# Поколение GPU 116, Лучшая точность: 0.440186
# Поколение GPU 117, Лучшая точность: 0.440186
# Поколение GPU 118, Лучшая точность: 0.199156
# Поколение GPU 119, Лучшая точность: 0.199156
# Поколение GPU 120, Лучшая точность: 0.199156
# Поколение GPU 121, Лучшая точность: 0.199156
# Поколение GPU 122, Лучшая точность: 0.199156
# Поколение GPU 123, Лучшая точность: 0.199156
# Поколение GPU 124, Лучшая точность: 0.199156
# Поколение GPU 125, Лучшая точность: 0.199156
# Поколение GPU 126, Лучшая точность: 0.199156
# Поколение GPU 127, Лучшая точность: 0.199156
# Поколение GPU 128, Лучшая точность: 0.199156
# Поколение GPU 129, Лучшая точность: 0.199156
# Поколение GPU 130, Лучшая точность: 0.199156
# Поколение GPU 131, Лучшая точность: 0.199156
# Поколение GPU 132, Лучшая точность: 0.199156
# Поколение GPU 133, Лучшая точность: 0.199156
# Поколение GPU 134, Лучшая точность: 0.194376
# Поколение GPU 135, Лучшая точность: 0.194376
# Поколение GPU 136, Лучшая точность: 0.194376
# Поколение GPU 137, Лучшая точность: 0.194376
# Поколение GPU 138, Лучшая точность: 0.194376
# Поколение GPU 139, Лучшая точность: 0.194376
# Поколение GPU 140, Лучшая точность: 0.194376
# Поколение GPU 141, Лучшая точность: 0.194376
# Поколение GPU 142, Лучшая точность: 0.194376
# Поколение GPU 143, Лучшая точность: 0.194376
# Поколение GPU 144, Лучшая точность: 0.194376
# Поколение GPU 145, Лучшая точность: 0.194376
# Поколение GPU 146, Лучшая точность: 0.194376
# Поколение GPU 147, Лучшая точность: 0.194376
# Поколение GPU 148, Лучшая точность: 0.194376
# Поколение GPU 149, Лучшая точность: 0.194376
# Поколение GPU 150, Лучшая точность: 0.194376
# Поколение GPU 151, Лучшая точность: 0.194376
# Поколение GPU 152, Лучшая точность: 0.194376
# Поколение GPU 153, Лучшая точность: 0.194376
# Поколение GPU 154, Лучшая точность: 0.190173
# Поколение GPU 155, Лучшая точность: 0.190173
# Поколение GPU 156, Лучшая точность: 0.190173
# Поколение GPU 157, Лучшая точность: 0.190173
# Поколение GPU 158, Лучшая точность: 0.190173
# Поколение GPU 159, Лучшая точность: 0.190173
# Поколение GPU 160, Лучшая точность: 0.190173
# Поколение GPU 161, Лучшая точность: 0.190173
# Поколение GPU 162, Лучшая точность: 0.190173
# Поколение GPU 163, Лучшая точность: 0.170122
# Поколение GPU 164, Лучшая точность: 0.170122
# Поколение GPU 165, Лучшая точность: 0.170122
# Поколение GPU 166, Лучшая точность: 0.170122
# Поколение GPU 167, Лучшая точность: 0.16264
# Поколение GPU 168, Лучшая точность: 0.16264
# Поколение GPU 169, Лучшая точность: 0.16264
# Поколение GPU 170, Лучшая точность: 0.16264
# Поколение GPU 171, Лучшая точность: 0.16264
# Поколение GPU 172, Лучшая точность: 0.16264
# Поколение GPU 173, Лучшая точность: 0.16264
# Поколение GPU 174, Лучшая точность: 0.16264
# Поколение GPU 175, Лучшая точность: 0.16264
# Поколение GPU 176, Лучшая точность: 0.16264
# Поколение GPU 177, Лучшая точность: 0.16264
# Поколение GPU 178, Лучшая точность: 0.16264
# Поколение GPU 179, Лучшая точность: 0.16264
# Поколение GPU 180, Лучшая точность: 0.16264
# Поколение GPU 181, Лучшая точность: 0.16264
# Поколение GPU 182, Лучшая точность: 0.16264
# Поколение GPU 183, Лучшая точность: 0.16264
# Поколение GPU 184, Лучшая точность: 0.16264
# Поколение GPU 185, Лучшая точность: 0.16264
# Поколение GPU 186, Лучшая точность: 0.16264
# Поколение GPU 187, Лучшая точность: 0.16264
# Поколение GPU 188, Лучшая точность: 0.16264
# Поколение GPU 189, Лучшая точность: 0.16264
# Поколение GPU 190, Лучшая точность: 0.16264
# Поколение GPU 191, Лучшая точность: 0.16264
# Поколение GPU 192, Лучшая точность: 0.16264
# Поколение GPU 193, Лучшая точность: 0.16264
# Поколение GPU 194, Лучшая точность: 0.16264
# Поколение GPU 195, Лучшая точность: 0.16264
# Поколение GPU 196, Лучшая точность: 0.16264
# Поколение GPU 197, Лучшая точность: 0.16264
# Поколение GPU 198, Лучшая точность: 0.16264
# Поколение GPU 199, Лучшая точность: 0.129578
# Поколение GPU 200, Лучшая точность: 0.129578
# Поколение GPU 201, Лучшая точность: 0.12516
# Поколение GPU 202, Лучшая точность: 0.12516
# Поколение GPU 203, Лучшая точность: 0.12516
# Поколение GPU 204, Лучшая точность: 0.12516
# Поколение GPU 205, Лучшая точность: 0.12516
# Поколение GPU 206, Лучшая точность: 0.12516
# Поколение GPU 207, Лучшая точность: 0.12516
# Поколение GPU 208, Лучшая точность: 0.12516
# Поколение GPU 209, Лучшая точность: 0.12516
# Поколение GPU 210, Лучшая точность: 0.12516
# Поколение GPU 211, Лучшая точность: 0.12516
# Поколение GPU 212, Лучшая точность: 0.12516
# Поколение GPU 213, Лучшая точность: 0.12516
# Поколение GPU 214, Лучшая точность: 0.12516
# Поколение GPU 215, Лучшая точность: 0.12516
# Поколение GPU 216, Лучшая точность: 0.12516
# Поколение GPU 217, Лучшая точность: 0.12516
# Поколение GPU 218, Лучшая точность: 0.12516
# Поколение GPU 219, Лучшая точность: 0.12516
# Поколение GPU 220, Лучшая точность: 0.0780596
# Поколение GPU 221, Лучшая точность: 0.0780596
# Поколение GPU 222, Лучшая точность: 0.0780596
# Поколение GPU 223, Лучшая точность: 0.0780596
# Поколение GPU 224, Лучшая точность: 0.0776259
# Поколение GPU 225, Лучшая точность: 0.0776259
# Поколение GPU 226, Лучшая точность: 0.0701386
# Поколение GPU 227, Лучшая точность: 0.0701386
# Поколение GPU 228, Лучшая точность: 0.0701386
# Поколение GPU 229, Лучшая точность: 0.0643139
# Поколение GPU 230, Лучшая точность: 0.0643139
# Поколение GPU 231, Лучшая точность: 0.0643139
# Поколение GPU 232, Лучшая точность: 0.0643139
# Поколение GPU 233, Лучшая точность: 0.0643139
# Поколение GPU 234, Лучшая точность: 0.0643139
# Поколение GPU 235, Лучшая точность: 0.0643139
# Поколение GPU 236, Лучшая точность: 0.0643139
# Поколение GPU 237, Лучшая точность: 0.0643139
# Поколение GPU 238, Лучшая точность: 0.0643139
# Поколение GPU 239, Лучшая точность: 0.0643139
# Поколение GPU 240, Лучшая точность: 0.0643139
# Поколение GPU 241, Лучшая точность: 0.0643139
# Поколение GPU 242, Лучшая точность: 0.0643139
# Поколение GPU 243, Лучшая точность: 0.0643139
# Поколение GPU 244, Лучшая точность: 0.0643139
# Поколение GPU 245, Лучшая точность: 0.0643139
# Поколение GPU 246, Лучшая точность: 0.0643139
# Поколение GPU 247, Лучшая точность: 0.0643139
# Поколение GPU 248, Лучшая точность: 0.0643139
# Поколение GPU 249, Лучшая точность: 0.0643139
# Поколение GPU 250, Лучшая точность: 0.0643139
# Поколение GPU 251, Лучшая точность: 0.0643139
# Поколение GPU 252, Лучшая точность: 0.0643139
# Поколение GPU 253, Лучшая точность: 0.0643139
# Поколение GPU 254, Лучшая точность: 0.0643139
# Поколение GPU 255, Лучшая точность: 0.0643139
# Поколение GPU 256, Лучшая точность: 0.0643139
# Поколение GPU 257, Лучшая точность: 0.0643139
# Поколение GPU 258, Лучшая точность: 0.0643139
# Поколение GPU 259, Лучшая точность: 0.0643139
# Поколение GPU 260, Лучшая точность: 0.0643139
# Поколение GPU 261, Лучшая точность: 0.0643139
# Поколение GPU 262, Лучшая точность: 0.0643139
# Поколение GPU 263, Лучшая точность: 0.0643139
# Поколение GPU 264, Лучшая точность: 0.0643139
# Поколение GPU 265, Лучшая точность: 0.0643139
# Поколение GPU 266, Лучшая точность: 0.0643139
# Поколение GPU 267, Лучшая точность: 0.0643139
# Поколение GPU 268, Лучшая точность: 0.0643139
# Поколение GPU 269, Лучшая точность: 0.0643139
# Поколение GPU 270, Лучшая точность: 0.0643139
# Поколение GPU 271, Лучшая точность: 0.0643139
# Поколение GPU 272, Лучшая точность: 0.0643139
# Поколение GPU 273, Лучшая точность: 0.0643139
# Поколение GPU 274, Лучшая точность: 0.0643139
# Поколение GPU 275, Лучшая точность: 0.0643139
# Поколение GPU 276, Лучшая точность: 0.0643139
# Поколение GPU 277, Лучшая точность: 0.0643139
# Поколение GPU 278, Лучшая точность: 0.0643139
# Поколение CPU 0, Лучшая точность: 82.5537
# Поколение CPU 1, Лучшая точность: 77.0542
# Поколение CPU 2, Лучшая точность: 77.0542
# Поколение CPU 3, Лучшая точность: 77.0542
# Поколение CPU 4, Лучшая точность: 77.0542
# Поколение CPU 5, Лучшая точность: 66.9954
# Поколение CPU 6, Лучшая точность: 38.1215
# Поколение CPU 7, Лучшая точность: 30.7639
# Поколение CPU 8, Лучшая точность: 15.6058
# Поколение CPU 9, Лучшая точность: 15.6058
# Поколение CPU 10, Лучшая точность: 8.39347
# Поколение CPU 11, Лучшая точность: 8.39347
# Поколение CPU 12, Лучшая точность: 8.39347
# Поколение CPU 13, Лучшая точность: 7.63897
# Поколение CPU 14, Лучшая точность: 1.91441
# Поколение CPU 15, Лучшая точность: 1.91441
# Поколение CPU 16, Лучшая точность: 1.91441
# Поколение CPU 17, Лучшая точность: 1.91441
# Поколение CPU 18, Лучшая точность: 1.91441
# Поколение CPU 19, Лучшая точность: 1.91441
# Поколение CPU 20, Лучшая точность: 1.91441
# Поколение CPU 21, Лучшая точность: 1.91441
# Поколение CPU 22, Лучшая точность: 1.91441
# Поколение CPU 23, Лучшая точность: 1.91441
# Поколение CPU 24, Лучшая точность: 1.91441
# Поколение CPU 25, Лучшая точность: 1.91441
# Поколение CPU 26, Лучшая точность: 1.91441
# Поколение CPU 27, Лучшая точность: 1.91441
# Поколение CPU 28, Лучшая точность: 1.03092
# Поколение CPU 29, Лучшая точность: 1.03092
# Поколение CPU 30, Лучшая точность: 1.03092
# Поколение CPU 31, Лучшая точность: 0.564968
# Поколение CPU 32, Лучшая точность: 0.564968
# Поколение CPU 33, Лучшая точность: 0.564968
# Поколение CPU 34, Лучшая точность: 0.564968
# Поколение CPU 35, Лучшая точность: 0.564968
# Поколение CPU 36, Лучшая точность: 0.564968
# Поколение CPU 37, Лучшая точность: 0.564968
# Поколение CPU 38, Лучшая точность: 0.564968
# Поколение CPU 39, Лучшая точность: 0.564968
# Поколение CPU 40, Лучшая точность: 0.564968
# Поколение CPU 41, Лучшая точность: 0.564968
# Поколение CPU 42, Лучшая точность: 0.564968
# Поколение CPU 43, Лучшая точность: 0.564968
# Поколение CPU 44, Лучшая точность: 0.564968
# Поколение CPU 45, Лучшая точность: 0.564968
# Поколение CPU 46, Лучшая точность: 0.564968
# Поколение CPU 47, Лучшая точность: 0.564968
# Поколение CPU 48, Лучшая точность: 0.564968
# Поколение CPU 49, Лучшая точность: 0.564968
# Поколение CPU 50, Лучшая точность: 0.564968
# Поколение CPU 51, Лучшая точность: 0.329793
# Поколение CPU 52, Лучшая точность: 0.329793
# Поколение CPU 53, Лучшая точность: 0.329793
# Поколение CPU 54, Лучшая точность: 0.329793
# Поколение CPU 55, Лучшая точность: 0.329793
# Поколение CPU 56, Лучшая точность: 0.329793
# Поколение CPU 57, Лучшая точность: 0.329793
# Поколение CPU 58, Лучшая точность: 0.329793
# Поколение CPU 59, Лучшая точность: 0.329793
# Поколение CPU 60, Лучшая точность: 0.329793
# Поколение CPU 61, Лучшая точность: 0.329793
# Поколение CPU 62, Лучшая точность: 0.296497
# Поколение CPU 63, Лучшая точность: 0.296497
# Поколение CPU 64, Лучшая точность: 0.296497
# Поколение CPU 65, Лучшая точность: 0.296497
# Поколение CPU 66, Лучшая точность: 0.296497
# Поколение CPU 67, Лучшая точность: 0.296497
# Поколение CPU 68, Лучшая точность: 0.296497
# Поколение CPU 69, Лучшая точность: 0.296497
# Поколение CPU 70, Лучшая точность: 0.296497
# Поколение CPU 71, Лучшая точность: 0.296497
# Поколение CPU 72, Лучшая точность: 0.296497
# Поколение CPU 73, Лучшая точность: 0.296497
# Поколение CPU 74, Лучшая точность: 0.296497
# Поколение CPU 75, Лучшая точность: 0.296497
# Поколение CPU 76, Лучшая точность: 0.296497
# Поколение CPU 77, Лучшая точность: 0.296497
# Поколение CPU 78, Лучшая точность: 0.296497
# Поколение CPU 79, Лучшая точность: 0.296497
# Поколение CPU 80, Лучшая точность: 0.296497
# Поколение CPU 81, Лучшая точность: 0.296497
# Поколение CPU 82, Лучшая точность: 0.296497
# Поколение CPU 83, Лучшая точность: 0.295238
# Поколение CPU 84, Лучшая точность: 0.295238
# Поколение CPU 85, Лучшая точность: 0.295238
# Поколение CPU 86, Лучшая точность: 0.295238
# Поколение CPU 87, Лучшая точность: 0.295238
# Поколение CPU 88, Лучшая точность: 0.295238
# Поколение CPU 89, Лучшая точность: 0.295238
# Поколение CPU 90, Лучшая точность: 0.295238
# Поколение CPU 91, Лучшая точность: 0.295238
# Поколение CPU 92, Лучшая точность: 0.295238
# Поколение CPU 93, Лучшая точность: 0.295238
# Поколение CPU 94, Лучшая точность: 0.295238
# Поколение CPU 95, Лучшая точность: 0.295238
# Поколение CPU 96, Лучшая точность: 0.295238
# Поколение CPU 97, Лучшая точность: 0.295238
# Поколение CPU 98, Лучшая точность: 0.295238
# Поколение CPU 99, Лучшая точность: 0.295238
# Поколение CPU 100, Лучшая точность: 0.295238
# Поколение CPU 101, Лучшая точность: 0.295238
# Поколение CPU 102, Лучшая точность: 0.295238
# Поколение CPU 103, Лучшая точность: 0.295238
# Поколение CPU 104, Лучшая точность: 0.295238
# Поколение CPU 105, Лучшая точность: 0.295238
# Поколение CPU 106, Лучшая точность: 0.295238
# Поколение CPU 107, Лучшая точность: 0.295238
# Поколение CPU 108, Лучшая точность: 0.295238
# Поколение CPU 109, Лучшая точность: 0.295238
# Поколение CPU 110, Лучшая точность: 0.295238
# Поколение CPU 111, Лучшая точность: 0.295238
# Поколение CPU 112, Лучшая точность: 0.295238
# Поколение CPU 113, Лучшая точность: 0.295238
# Поколение CPU 114, Лучшая точность: 0.295238
# Поколение CPU 115, Лучшая точность: 0.295238
# Поколение CPU 116, Лучшая точность: 0.295238
# Поколение CPU 117, Лучшая точность: 0.295238
# Поколение CPU 118, Лучшая точность: 0.295238
# Поколение CPU 119, Лучшая точность: 0.295238
# Поколение CPU 120, Лучшая точность: 0.295238
# Поколение CPU 121, Лучшая точность: 0.295238
# Поколение CPU 122, Лучшая точность: 0.295238
# Поколение CPU 123, Лучшая точность: 0.295238
# Поколение CPU 124, Лучшая точность: 0.295238
# Поколение CPU 125, Лучшая точность: 0.295238
# Поколение CPU 126, Лучшая точность: 0.295238
# Поколение CPU 127, Лучшая точность: 0.295238
# Поколение CPU 128, Лучшая точность: 0.295238
# Поколение CPU 129, Лучшая точность: 0.295238
# Поколение CPU 130, Лучшая точность: 0.295238
# Поколение CPU 131, Лучшая точность: 0.295238
# Поколение CPU 132, Лучшая точность: 0.295238
# Заданные коэффициенты: 1.54861 -4.30762 2.41116 2.33911 -3.77897
# Точность: 0.295238. Время выполнения CPU: 697.983. Лучшие коэффициенты полинома CPU: 1.38495 -3.96426 2.3451 2.31645 -3.77474
# Точность: 0.0643139. Время выполнения GPU: 16.6475. Лучшие коэффициенты полинома GPU: 1.76192 -4.47121 2.3344 2.34749 -3.77559

# %%
# %%cuda
# // версия в которой происходили эксперементы с лабораторной работой
# // не совсем так как описывается в файле методичке
# // основное отличие в том, то в новом поколение, я не использую старое
# #include <iostream>
# #include <vector>
# #include <cmath>
# #include <algorithm>
# #include <random>
# #include <limits>
#
# const double left = -5.0; // граница слева
# const double right = 5.0; // граница справа
# const int number_points = 100; // количество точек
# const double step = (right - left)/number_points; // шаг для x
# const int POPULATION_SIZE = 1000; // Размер популяции
# const int MAX_GENERATION = 1000; // Максимальное количество поколений
# const double MUTATION_RATE = 0.01; // Вероятность мутации
# const double TARGET_ERROR = 1e-5; // целевая ошибка
# const int POLYNOMYAL_DEGREE = 4; // степень полинома
# const double COEF_SELECTION = 0.5;
#
#
# // Точки по которым высчитываем зачение функции
# std::vector<double> POINTS;
# // Значение функции
# std::vector<double> FUNCTION_VALUES;
# // Целевой полином, коэффициенты которого хотим найти
# std::vector<double> TARGET_POLYNOM(POLYNOMYAL_DEGREE+1);
#
# // Генератор случайных чисел
# std::random_device rd;
# std::mt19937 gen(rd());
# std::uniform_real_distribution<> dis(left, right);
# std::uniform_real_distribution<> dis_mutation(0.0, 1.0);
# std::uniform_real_distribution<> mutation_dist(0.0, 5.0);
#
#
# // подсчет значения функции
# double function_value(std::vector<double> polynom, float x){
#     double result = 0;
#     for(int i = 0; i<polynom.size(); i++) {result += polynom[i]*std::pow(x,i);}
#     return result;
# }
#
# // Инициализация значений (коэффициены целевого полинома, точки, значения фукнций по точкам)
# void initFuncValues(){
#     for(double& value: TARGET_POLYNOM) value = dis(gen);
#     for(double point = left; point < right; point+= step){
#         POINTS.push_back(point);
#         FUNCTION_VALUES.push_back(function_value(TARGET_POLYNOM,point));
#     }
# }
#
# // Тип для индивидуума (коэффициенты полинома)
# using Individual = std::vector<double>;
#
# // Шаги алгоритма
# // Инициализация начальной популяции
# // Оценка пригодности (вычисление ошибки)
# // Отбор индивидов по значению пригодности
# // Скрещивание
# // Мутации
#
# std::vector<Individual> initPopulation(){
#     std::vector<Individual> population;
#     for(int i = 0; i < POPULATION_SIZE; i++){
#         Individual individual(POLYNOMYAL_DEGREE+1);
#         for(double& ind: individual){
#             ind = dis(gen);
#         }
#         population.push_back(individual);
#     }
#     return population;
# }
#
# // ищем ошибку
# double fitness(const Individual& individual){
#     double error = 0.0;
#     for(int i = 0; i<POINTS.size(); i++){
#         double aprox = function_value(individual, POINTS[i]);
#         error += std::pow(FUNCTION_VALUES[i]-aprox,2);
#     }
#     return error/POINTS.size();
# }
#
# // отбор
# std::vector<Individual> select(std::vector<Individual> population){
#     std::sort(population.begin(),population.end(), [](const Individual& a, const Individual& b){return fitness(a)<fitness(b);});
#     return std::vector<Individual>(population.begin(), population.begin() + population.size()*COEF_SELECTION);
# }
#
# // скрещивание
# Individual crossover(const Individual& parent1, const Individual& parent2) {
#     Individual child(POLYNOMYAL_DEGREE+1);
#     for(int i = 0; i<=POLYNOMYAL_DEGREE; i++){
#         if(gen()%2==0){
#             child[i] = parent1[i];
#         }else{
#             child[i] = parent2[i];
#         }
#     }
#     return child;
# }
#
#
# Individual crossover_posl(const Individual& parent1, const Individual& parent2) {
#     int cross_point = 1 + gen() % (POLYNOMYAL_DEGREE - 1);
#     Individual child(POLYNOMYAL_DEGREE+1);
#     for(int i = 0; i<cross_point; i++) child[i] = parent1[i];
#     for(int i = cross_point; i<=POLYNOMYAL_DEGREE;i++) child[i] = parent2[i];
#     return child;
# }
#
#
# void mutate(Individual& individual, double mean = 0.0, double var = 0.1) {
#     std::normal_distribution<> gaussian(mean, var);
#     for (double& gene : individual) {
#         if (std::uniform_real_distribution<>(0.0, 1.0)(gen) < MUTATION_RATE) {
#             gene += gaussian(gen); // Добавляем случайное значение из нормального распределения
#         }
#     }
# }
#
# /*
# void mutate_v2(Individual& individual) {
#     for (double& coeff : individual) {
#         if (dis_mutation(gen) < MUTATION_RATE) {
#             coeff *= mutation_dist(gen)*10;
#         }
#     }
# }
# */
#
#
# Individual geneticAlgorithm(){
#     // инициализируем популяцию
#     std::vector<Individual> population = initPopulation();
#     Individual bestIndividual = population[0];
#     double bestFitness = fitness(bestIndividual);
#
#     for(int generation = 0; generation<MAX_GENERATION; generation++){
#         // отбираем лучших `родителей`
#         population = select(population);
#
#         std::vector<Individual> newPopulation;
#
#         // скрешиваем
#         while(newPopulation.size()<POPULATION_SIZE){
#             /*int p1Id = gen()%population.size();
#             int p2Id = p1Id;
#             while(p2Id!=p1Id) p2Id = gen()%population.size();*/
#
#             const Individual& parent1 = population[gen()%population.size()];
#             const Individual& parent2 = population[gen()%population.size()];
#             // создание ребенка между двумя различными родителями
#             Individual child = crossover(parent1, parent2);
#
#             // применяем мутацию
#             mutate(child);
#
#             newPopulation.push_back(child);
#         }
#         population = newPopulation;
#
#
#         // выбираем лучшего индивида
#         Individual currentIndividual = *std::min_element(population.begin(),population.end(), [](const Individual& a, const Individual& b){return fitness(a)<fitness(b);});
#
#         double currentFitness = fitness(currentIndividual);
#
#         if(currentFitness<bestFitness){
#             bestFitness = currentFitness;
#             bestIndividual = currentIndividual;
#         }
#
#         std::cout << "Поколение " << generation << ", Лучшая пригодность: " << bestFitness << std::endl;
#
#         // Остановка, если достигнута целевая ошибка
#         if (bestFitness < TARGET_ERROR) break;
#
#     }
#     return bestIndividual;
# }
#
#
#
#
# int main() {
#     //std::cout<<gen<<std::endl;
#     //std::cout<<dis(gen)<<std::endl;
#
#
#     initFuncValues();
#
#
#
#     Individual best_solution = geneticAlgorithm();
#
#
#     std::cout << "Заданные коэффициенты: ";
#     for (double coeff : TARGET_POLYNOM) {
#         std::cout << coeff << " ";
#     }
#     std::cout << std::endl;
#     std::cout << "Лучшие коэффициенты полинома: ";
#     for (double coeff : best_solution) {
#         std::cout << coeff << " ";
#     }
#     std::cout << std::endl;
#
#
#
#     return 0;
# }
# Out:
# Поколение 0, Лучшая пригодность: 648.345
# Поколение 1, Лучшая пригодность: 250.818
# Поколение 2, Лучшая пригодность: 57.5431
# Поколение 3, Лучшая пригодность: 57.5431
# Поколение 4, Лучшая пригодность: 11.9251
# Поколение 5, Лучшая пригодность: 11.9251
# Поколение 6, Лучшая пригодность: 11.9251
# Поколение 7, Лучшая пригодность: 11.9251
# Поколение 8, Лучшая пригодность: 10.2995
# Поколение 9, Лучшая пригодность: 4.3588
# Поколение 10, Лучшая пригодность: 4.3588
# Поколение 11, Лучшая пригодность: 4.3588
# Поколение 12, Лучшая пригодность: 4.3588
# Поколение 13, Лучшая пригодность: 4.3588
# Поколение 14, Лучшая пригодность: 4.3588
# Поколение 15, Лучшая пригодность: 4.3588
# Поколение 16, Лучшая пригодность: 4.3588
# Поколение 17, Лучшая пригодность: 4.3588
# Поколение 18, Лучшая пригодность: 4.3588
# Поколение 19, Лучшая пригодность: 4.3588
# Поколение 20, Лучшая пригодность: 4.3588
# Поколение 21, Лучшая пригодность: 4.3588
# Поколение 22, Лучшая пригодность: 4.3588
# Поколение 23, Лучшая пригодность: 4.3588
# Поколение 24, Лучшая пригодность: 4.3588
# Поколение 25, Лучшая пригодность: 4.3588
# Поколение 26, Лучшая пригодность: 4.3588
# Поколение 27, Лучшая пригодность: 4.3588
# Поколение 28, Лучшая пригодность: 4.3588
# Поколение 29, Лучшая пригодность: 4.3588
# Поколение 30, Лучшая пригодность: 4.3588
# Поколение 31, Лучшая пригодность: 4.3588
# Поколение 32, Лучшая пригодность: 4.3588
# Поколение 33, Лучшая пригодность: 4.3588
# Поколение 34, Лучшая пригодность: 4.3588
# Поколение 35, Лучшая пригодность: 4.3588
# Поколение 36, Лучшая пригодность: 4.3588
# Поколение 37, Лучшая пригодность: 4.3588
# Поколение 38, Лучшая пригодность: 4.3588
# Поколение 39, Лучшая пригодность: 4.3588
# Поколение 40, Лучшая пригодность: 4.3588
# Поколение 41, Лучшая пригодность: 4.3588
# Поколение 42, Лучшая пригодность: 4.3588
# Поколение 43, Лучшая пригодность: 4.3588
# Поколение 44, Лучшая пригодность: 4.3588
# Поколение 45, Лучшая пригодность: 4.3588
# Поколение 46, Лучшая пригодность: 4.3588
# Поколение 47, Лучшая пригодность: 4.3588
# Поколение 48, Лучшая пригодность: 4.3588
# Поколение 49, Лучшая пригодность: 4.3588
# Поколение 50, Лучшая пригодность: 4.3588
# Поколение 51, Лучшая пригодность: 4.3588
# Поколение 52, Лучшая пригодность: 4.3588
# Поколение 53, Лучшая пригодность: 4.3588
# Поколение 54, Лучшая пригодность: 4.3588
# Поколение 55, Лучшая пригодность: 4.3588
# Поколение 56, Лучшая пригодность: 4.3588
# Поколение 57, Лучшая пригодность: 4.3588
# Поколение 58, Лучшая пригодность: 4.3588
# Поколение 59, Лучшая пригодность: 4.3588
# Поколение 60, Лучшая пригодность: 4.3588
# Поколение 61, Лучшая пригодность: 4.3588
# Поколение 62, Лучшая пригодность: 4.3588
# Поколение 63, Лучшая пригодность: 4.3588
# Поколение 64, Лучшая пригодность: 4.3588
# Поколение 65, Лучшая пригодность: 4.3588
# Поколение 66, Лучшая пригодность: 4.3588
# Поколение 67, Лучшая пригодность: 4.3588
# Поколение 68, Лучшая пригодность: 4.3588
# Поколение 69, Лучшая пригодность: 4.3588
# Поколение 70, Лучшая пригодность: 4.3588
# Поколение 71, Лучшая пригодность: 4.3588
# Поколение 72, Лучшая пригодность: 4.3588
# Поколение 73, Лучшая пригодность: 4.3588
# Поколение 74, Лучшая пригодность: 4.3588
# Поколение 75, Лучшая пригодность: 4.3588
# Поколение 76, Лучшая пригодность: 4.3588
# Поколение 77, Лучшая пригодность: 4.3588
# Поколение 78, Лучшая пригодность: 4.3588
# Поколение 79, Лучшая пригодность: 4.3588
# Поколение 80, Лучшая пригодность: 4.3588
# Поколение 81, Лучшая пригодность: 4.3588
# Поколение 82, Лучшая пригодность: 4.3588
# Поколение 83, Лучшая пригодность: 4.3588
# Поколение 84, Лучшая пригодность: 4.3588
# Поколение 85, Лучшая пригодность: 4.3588
# Поколение 86, Лучшая пригодность: 4.3588
# Поколение 87, Лучшая пригодность: 4.3588
# Поколение 88, Лучшая пригодность: 4.3588
# Поколение 89, Лучшая пригодность: 4.3588
# Поколение 90, Лучшая пригодность: 4.3588
# Поколение 91, Лучшая пригодность: 4.3588
# Поколение 92, Лучшая пригодность: 4.3588
# Поколение 93, Лучшая пригодность: 4.3588
# Поколение 94, Лучшая пригодность: 4.3588
# Поколение 95, Лучшая пригодность: 4.3588
# Поколение 96, Лучшая пригодность: 4.3588
# Поколение 97, Лучшая пригодность: 4.3588
# Поколение 98, Лучшая пригодность: 4.3588
# Поколение 99, Лучшая пригодность: 4.3588
# Поколение 100, Лучшая пригодность: 4.3588
# Поколение 101, Лучшая пригодность: 4.3588
# Поколение 102, Лучшая пригодность: 4.3588
# Поколение 103, Лучшая пригодность: 4.3588
# Поколение 104, Лучшая пригодность: 4.3588
# Поколение 105, Лучшая пригодность: 4.3588
# Поколение 106, Лучшая пригодность: 4.3588
# Поколение 107, Лучшая пригодность: 4.3588
# Поколение 108, Лучшая пригодность: 4.3588
# Поколение 109, Лучшая пригодность: 4.3588
# Поколение 110, Лучшая пригодность: 4.3588
# Поколение 111, Лучшая пригодность: 4.3588
# Поколение 112, Лучшая пригодность: 4.3588
# Поколение 113, Лучшая пригодность: 4.3588
# Поколение 114, Лучшая пригодность: 4.3588
# Поколение 115, Лучшая пригодность: 4.3588
# Поколение 116, Лучшая пригодность: 4.3588
# Поколение 117, Лучшая пригодность: 4.3588
# Поколение 118, Лучшая пригодность: 4.3588
# Поколение 119, Лучшая пригодность: 4.3588
# Поколение 120, Лучшая пригодность: 4.3588
# Поколение 121, Лучшая пригодность: 4.3588
# Поколение 122, Лучшая пригодность: 4.3588
# Поколение 123, Лучшая пригодность: 4.3588
# Поколение 124, Лучшая пригодность: 4.3588
# Поколение 125, Лучшая пригодность: 4.3588
# Поколение 126, Лучшая пригодность: 4.3588
# Поколение 127, Лучшая пригодность: 4.3588
# Поколение 128, Лучшая пригодность: 4.3588
# Поколение 129, Лучшая пригодность: 4.3588
# Поколение 130, Лучшая пригодность: 4.3588
# Поколение 131, Лучшая пригодность: 4.3588
# Поколение 132, Лучшая пригодность: 4.3588
# Поколение 133, Лучшая пригодность: 4.3588
# Поколение 134, Лучшая пригодность: 4.3588
# Поколение 135, Лучшая пригодность: 4.3588
# Поколение 136, Лучшая пригодность: 4.3588
# Поколение 137, Лучшая пригодность: 4.3588
# Поколение 138, Лучшая пригодность: 4.3588
# Поколение 139, Лучшая пригодность: 4.3588
# Поколение 140, Лучшая пригодность: 4.3588
# Поколение 141, Лучшая пригодность: 4.3588
# Поколение 142, Лучшая пригодность: 4.3588
# Поколение 143, Лучшая пригодность: 4.3588
# Поколение 144, Лучшая пригодность: 4.3588
# Поколение 145, Лучшая пригодность: 4.3588
# Поколение 146, Лучшая пригодность: 4.3588
# Поколение 147, Лучшая пригодность: 4.3588
# Поколение 148, Лучшая пригодность: 4.3588
# Поколение 149, Лучшая пригодность: 4.3588
# Поколение 150, Лучшая пригодность: 4.3588
# Поколение 151, Лучшая пригодность: 4.3588
# Поколение 152, Лучшая пригодность: 4.3588
# Поколение 153, Лучшая пригодность: 4.3588
# Поколение 154, Лучшая пригодность: 4.3588
# Поколение 155, Лучшая пригодность: 4.3588
# Поколение 156, Лучшая пригодность: 4.3588
# Поколение 157, Лучшая пригодность: 4.3588
# Поколение 158, Лучшая пригодность: 4.3588
# Поколение 159, Лучшая пригодность: 4.3588
# Поколение 160, Лучшая пригодность: 4.3588
# Поколение 161, Лучшая пригодность: 4.3588
# Поколение 162, Лучшая пригодность: 4.3588
# Поколение 163, Лучшая пригодность: 4.3588
# Поколение 164, Лучшая пригодность: 4.3588
# Поколение 165, Лучшая пригодность: 4.3588
# Поколение 166, Лучшая пригодность: 4.3588
# Поколение 167, Лучшая пригодность: 4.3588
# Поколение 168, Лучшая пригодность: 4.3588
# Поколение 169, Лучшая пригодность: 4.3588
# Поколение 170, Лучшая пригодность: 4.3588
# Поколение 171, Лучшая пригодность: 4.3588
# Поколение 172, Лучшая пригодность: 4.3588
# Поколение 173, Лучшая пригодность: 4.3588
# Поколение 174, Лучшая пригодность: 4.3588
# Поколение 175, Лучшая пригодность: 4.3588
# Поколение 176, Лучшая пригодность: 4.3588
# Поколение 177, Лучшая пригодность: 4.3588
# Поколение 178, Лучшая пригодность: 4.3588
# Поколение 179, Лучшая пригодность: 4.3204
# Поколение 180, Лучшая пригодность: 4.31718
# Поколение 181, Лучшая пригодность: 4.31382
# Поколение 182, Лучшая пригодность: 4.30582
# Поколение 183, Лучшая пригодность: 4.30582
# Поколение 184, Лучшая пригодность: 4.30582
# Поколение 185, Лучшая пригодность: 4.30582
# Поколение 186, Лучшая пригодность: 4.30582
# Поколение 187, Лучшая пригодность: 4.30582
# Поколение 188, Лучшая пригодность: 4.20733
# Поколение 189, Лучшая пригодность: 4.20733
# Поколение 190, Лучшая пригодность: 4.20733
# Поколение 191, Лучшая пригодность: 4.20733
# Поколение 192, Лучшая пригодность: 4.20733
# Поколение 193, Лучшая пригодность: 4.20733
# Поколение 194, Лучшая пригодность: 4.20733
# Поколение 195, Лучшая пригодность: 4.20733
# Поколение 196, Лучшая пригодность: 4.20733
# Поколение 197, Лучшая пригодность: 4.20733
# Поколение 198, Лучшая пригодность: 4.20733
# Поколение 199, Лучшая пригодность: 4.20733
# Поколение 200, Лучшая пригодность: 4.20733
# Поколение 201, Лучшая пригодность: 4.20733
# Поколение 202, Лучшая пригодность: 4.20733
# Поколение 203, Лучшая пригодность: 4.20733
# Поколение 204, Лучшая пригодность: 4.20733
# Поколение 205, Лучшая пригодность: 4.20733
# Поколение 206, Лучшая пригодность: 4.20733
# Поколение 207, Лучшая пригодность: 4.20733
# Поколение 208, Лучшая пригодность: 4.09647
# Поколение 209, Лучшая пригодность: 4.09647
# Поколение 210, Лучшая пригодность: 4.09596
# Поколение 211, Лучшая пригодность: 4.09596
# Поколение 212, Лучшая пригодность: 4.09596
# Поколение 213, Лучшая пригодность: 4.09596
# Поколение 214, Лучшая пригодность: 4.09596
# Поколение 215, Лучшая пригодность: 3.96862
# Поколение 216, Лучшая пригодность: 3.96731
# Поколение 217, Лучшая пригодность: 3.96731
# Поколение 218, Лучшая пригодность: 3.96241
# Поколение 219, Лучшая пригодность: 3.92244
# Поколение 220, Лучшая пригодность: 3.88716
# Поколение 221, Лучшая пригодность: 3.88716
# Поколение 222, Лучшая пригодность: 3.88716
# Поколение 223, Лучшая пригодность: 3.88716
# Поколение 224, Лучшая пригодность: 3.88716
# Поколение 225, Лучшая пригодность: 3.88494
# Поколение 226, Лучшая пригодность: 3.87221
# Поколение 227, Лучшая пригодность: 3.87221
# Поколение 228, Лучшая пригодность: 3.87221
# Поколение 229, Лучшая пригодность: 3.87192
# Поколение 230, Лучшая пригодность: 3.87186
# Поколение 231, Лучшая пригодность: 3.87186
# Поколение 232, Лучшая пригодность: 3.87152
# Поколение 233, Лучшая пригодность: 3.86207
# Поколение 234, Лучшая пригодность: 3.86207
# Поколение 235, Лучшая пригодность: 3.86207
# Поколение 236, Лучшая пригодность: 3.86112
# Поколение 237, Лучшая пригодность: 3.86071
# Поколение 238, Лучшая пригодность: 3.85096
# Поколение 239, Лучшая пригодность: 3.84943
# Поколение 240, Лучшая пригодность: 3.84943
# Поколение 241, Лучшая пригодность: 3.84943
# Поколение 242, Лучшая пригодность: 3.84943
# Поколение 243, Лучшая пригодность: 3.84943
# Поколение 244, Лучшая пригодность: 3.84939
# Поколение 245, Лучшая пригодность: 3.84924
# Поколение 246, Лучшая пригодность: 3.84924
# Поколение 247, Лучшая пригодность: 3.84921
# Поколение 248, Лучшая пригодность: 3.82198
# Поколение 249, Лучшая пригодность: 3.70941
# Поколение 250, Лучшая пригодность: 3.70941
# Поколение 251, Лучшая пригодность: 3.15125
# Поколение 252, Лучшая пригодность: 3.15125
# Поколение 253, Лучшая пригодность: 3.15125
# Поколение 254, Лучшая пригодность: 3.15125
# Поколение 255, Лучшая пригодность: 3.15125
# Поколение 256, Лучшая пригодность: 3.15125
# Поколение 257, Лучшая пригодность: 3.15125
# Поколение 258, Лучшая пригодность: 3.15125
# Поколение 259, Лучшая пригодность: 3.1468
# Поколение 260, Лучшая пригодность: 3.14665
# Поколение 261, Лучшая пригодность: 3.14665
# Поколение 262, Лучшая пригодность: 3.14665
# Поколение 263, Лучшая пригодность: 2.845
# Поколение 264, Лучшая пригодность: 2.83842
# Поколение 265, Лучшая пригодность: 2.83842
# Поколение 266, Лучшая пригодность: 2.83842
# Поколение 267, Лучшая пригодность: 2.83842
# Поколение 268, Лучшая пригодность: 2.76632
# Поколение 269, Лучшая пригодность: 2.76577
# Поколение 270, Лучшая пригодность: 2.76414
# Поколение 271, Лучшая пригодность: 2.76414
# Поколение 272, Лучшая пригодность: 2.76414
# Поколение 273, Лучшая пригодность: 2.76373
# Поколение 274, Лучшая пригодность: 2.76373
# Поколение 275, Лучшая пригодность: 2.76373
# Поколение 276, Лучшая пригодность: 2.76373
# Поколение 277, Лучшая пригодность: 2.76373
# Поколение 278, Лучшая пригодность: 2.76373
# Поколение 279, Лучшая пригодность: 2.76373
# Поколение 280, Лучшая пригодность: 2.76373
# Поколение 281, Лучшая пригодность: 2.76373
# Поколение 282, Лучшая пригодность: 2.76373
# Поколение 283, Лучшая пригодность: 2.76373
# Поколение 284, Лучшая пригодность: 2.64803
# Поколение 285, Лучшая пригодность: 2.63075
# Поколение 286, Лучшая пригодность: 2.59722
# Поколение 287, Лучшая пригодность: 2.59473
# Поколение 288, Лучшая пригодность: 2.58646
# Поколение 289, Лучшая пригодность: 2.58646
# Поколение 290, Лучшая пригодность: 2.58646
# Поколение 291, Лучшая пригодность: 2.58646
# Поколение 292, Лучшая пригодность: 2.58646
# Поколение 293, Лучшая пригодность: 2.58646
# Поколение 294, Лучшая пригодность: 2.55875
# Поколение 295, Лучшая пригодность: 2.55875
# Поколение 296, Лучшая пригодность: 2.55875
# Поколение 297, Лучшая пригодность: 2.45161
# Поколение 298, Лучшая пригодность: 2.45161
# Поколение 299, Лучшая пригодность: 2.45161
# Поколение 300, Лучшая пригодность: 2.45161
# Поколение 301, Лучшая пригодность: 2.45161
# Поколение 302, Лучшая пригодность: 2.45161
# Поколение 303, Лучшая пригодность: 2.45161
# Поколение 304, Лучшая пригодность: 2.2014
# Поколение 305, Лучшая пригодность: 2.19988
# Поколение 306, Лучшая пригодность: 2.19988
# Поколение 307, Лучшая пригодность: 2.19289
# Поколение 308, Лучшая пригодность: 2.19289
# Поколение 309, Лучшая пригодность: 2.16929
# Поколение 310, Лучшая пригодность: 2.16929
# Поколение 311, Лучшая пригодность: 2.16929
# Поколение 312, Лучшая пригодность: 2.16929
# Поколение 313, Лучшая пригодность: 2.1596
# Поколение 314, Лучшая пригодность: 2.1596
# Поколение 315, Лучшая пригодность: 2.1596
# Поколение 316, Лучшая пригодность: 2.1596
# Поколение 317, Лучшая пригодность: 2.12542
# Поколение 318, Лучшая пригодность: 2.12542
# Поколение 319, Лучшая пригодность: 2.12542
# Поколение 320, Лучшая пригодность: 2.12542
# Поколение 321, Лучшая пригодность: 2.12542
# Поколение 322, Лучшая пригодность: 2.12542
# Поколение 323, Лучшая пригодность: 2.12542
# Поколение 324, Лучшая пригодность: 2.12542
# Поколение 325, Лучшая пригодность: 2.12542
# Поколение 326, Лучшая пригодность: 2.10696
# Поколение 327, Лучшая пригодность: 2.10696
# Поколение 328, Лучшая пригодность: 2.10696
# Поколение 329, Лучшая пригодность: 2.10696
# Поколение 330, Лучшая пригодность: 2.10696
# Поколение 331, Лучшая пригодность: 2.10696
# Поколение 332, Лучшая пригодность: 2.10696
# Поколение 333, Лучшая пригодность: 2.10696
# Поколение 334, Лучшая пригодность: 2.10069
# Поколение 335, Лучшая пригодность: 2.09489
# Поколение 336, Лучшая пригодность: 2.09424
# Поколение 337, Лучшая пригодность: 2.09424
# Поколение 338, Лучшая пригодность: 2.09394
# Поколение 339, Лучшая пригодность: 2.09394
# Поколение 340, Лучшая пригодность: 2.09394
# Поколение 341, Лучшая пригодность: 2.09394
# Поколение 342, Лучшая пригодность: 2.09394
# Поколение 343, Лучшая пригодность: 2.0933
# Поколение 344, Лучшая пригодность: 2.0933
# Поколение 345, Лучшая пригодность: 2.09275
# Поколение 346, Лучшая пригодность: 2.00518
# Поколение 347, Лучшая пригодность: 2.00518
# Поколение 348, Лучшая пригодность: 2.00518
# Поколение 349, Лучшая пригодность: 1.96315
# Поколение 350, Лучшая пригодность: 1.96315
# Поколение 351, Лучшая пригодность: 1.96315
# Поколение 352, Лучшая пригодность: 1.96315
# Поколение 353, Лучшая пригодность: 1.96315
# Поколение 354, Лучшая пригодность: 1.94064
# Поколение 355, Лучшая пригодность: 1.93952
# Поколение 356, Лучшая пригодность: 1.92583
# Поколение 357, Лучшая пригодность: 1.92583
# Поколение 358, Лучшая пригодность: 1.92583
# Поколение 359, Лучшая пригодность: 1.90336
# Поколение 360, Лучшая пригодность: 1.90336
# Поколение 361, Лучшая пригодность: 1.90336
# Поколение 362, Лучшая пригодность: 1.90336
# Поколение 363, Лучшая пригодность: 1.90336
# Поколение 364, Лучшая пригодность: 1.79534
# Поколение 365, Лучшая пригодность: 1.79534
# Поколение 366, Лучшая пригодность: 1.79358
# Поколение 367, Лучшая пригодность: 1.79358
# Поколение 368, Лучшая пригодность: 1.79358
# Поколение 369, Лучшая пригодность: 1.79207
# Поколение 370, Лучшая пригодность: 1.79207
# Поколение 371, Лучшая пригодность: 1.79207
# Поколение 372, Лучшая пригодность: 1.79207
# Поколение 373, Лучшая пригодность: 1.79207
# Поколение 374, Лучшая пригодность: 1.79207
# Поколение 375, Лучшая пригодность: 1.79207
# Поколение 376, Лучшая пригодность: 1.79207
# Поколение 377, Лучшая пригодность: 1.79207
# Поколение 378, Лучшая пригодность: 1.76951
# Поколение 379, Лучшая пригодность: 1.74812
# Поколение 380, Лучшая пригодность: 1.74812
# Поколение 381, Лучшая пригодность: 1.74812
# Поколение 382, Лучшая пригодность: 1.74789
# Поколение 383, Лучшая пригодность: 1.74789
# Поколение 384, Лучшая пригодность: 1.74789
# Поколение 385, Лучшая пригодность: 1.74789
# Поколение 386, Лучшая пригодность: 1.74789
# Поколение 387, Лучшая пригодность: 1.74789
# Поколение 388, Лучшая пригодность: 1.74789
# Поколение 389, Лучшая пригодность: 1.74032
# Поколение 390, Лучшая пригодность: 1.74032
# Поколение 391, Лучшая пригодность: 1.73309
# Поколение 392, Лучшая пригодность: 1.676
# Поколение 393, Лучшая пригодность: 1.676
# Поколение 394, Лучшая пригодность: 1.676
# Поколение 395, Лучшая пригодность: 1.676
# Поколение 396, Лучшая пригодность: 1.676
# Поколение 397, Лучшая пригодность: 1.676
# Поколение 398, Лучшая пригодность: 1.676
# Поколение 399, Лучшая пригодность: 1.676
# Поколение 400, Лучшая пригодность: 1.676
# Поколение 401, Лучшая пригодность: 1.676
# Поколение 402, Лучшая пригодность: 1.676
# Поколение 403, Лучшая пригодность: 1.676
# Поколение 404, Лучшая пригодность: 1.676
# Поколение 405, Лучшая пригодность: 1.676
# Поколение 406, Лучшая пригодность: 1.676
# Поколение 407, Лучшая пригодность: 1.676
# Поколение 408, Лучшая пригодность: 1.676
# Поколение 409, Лучшая пригодность: 1.676
# Поколение 410, Лучшая пригодность: 1.676
# Поколение 411, Лучшая пригодность: 1.676
# Поколение 412, Лучшая пригодность: 1.676
# Поколение 413, Лучшая пригодность: 1.66997
# Поколение 414, Лучшая пригодность: 1.66893
# Поколение 415, Лучшая пригодность: 1.63365
# Поколение 416, Лучшая пригодность: 1.63365
# Поколение 417, Лучшая пригодность: 1.63365
# Поколение 418, Лучшая пригодность: 1.5968
# Поколение 419, Лучшая пригодность: 1.5968
# Поколение 420, Лучшая пригодность: 1.5968
# Поколение 421, Лучшая пригодность: 1.5968
# Поколение 422, Лучшая пригодность: 1.5968
# Поколение 423, Лучшая пригодность: 1.5968
# Поколение 424, Лучшая пригодность: 1.53915
# Поколение 425, Лучшая пригодность: 1.53915
# Поколение 426, Лучшая пригодность: 1.53902
# Поколение 427, Лучшая пригодность: 1.53902
# Поколение 428, Лучшая пригодность: 1.53728
# Поколение 429, Лучшая пригодность: 1.53728
# Поколение 430, Лучшая пригодность: 1.53513
# Поколение 431, Лучшая пригодность: 1.535
# Поколение 432, Лучшая пригодность: 1.53437
# Поколение 433, Лучшая пригодность: 1.53437
# Поколение 434, Лучшая пригодность: 1.37625
# Поколение 435, Лучшая пригодность: 1.37625
# Поколение 436, Лучшая пригодность: 1.26262
# Поколение 437, Лучшая пригодность: 1.26262
# Поколение 438, Лучшая пригодность: 1.26262
# Поколение 439, Лучшая пригодность: 1.26262
# Поколение 440, Лучшая пригодность: 1.26262
# Поколение 441, Лучшая пригодность: 1.26262
# Поколение 442, Лучшая пригодность: 1.26262
# Поколение 443, Лучшая пригодность: 1.26262
# Поколение 444, Лучшая пригодность: 1.26262
# Поколение 445, Лучшая пригодность: 1.26262
# Поколение 446, Лучшая пригодность: 1.26262
# Поколение 447, Лучшая пригодность: 1.26262
# Поколение 448, Лучшая пригодность: 1.26262
# Поколение 449, Лучшая пригодность: 1.26262
# Поколение 450, Лучшая пригодность: 1.26262
# Поколение 451, Лучшая пригодность: 1.26262
# Поколение 452, Лучшая пригодность: 1.26262
# Поколение 453, Лучшая пригодность: 1.26262
# Поколение 454, Лучшая пригодность: 1.26262
# Поколение 455, Лучшая пригодность: 1.26262
# Поколение 456, Лучшая пригодность: 1.26262
# Поколение 457, Лучшая пригодность: 1.26262
# Поколение 458, Лучшая пригодность: 1.26262
# Поколение 459, Лучшая пригодность: 1.20939
# Поколение 460, Лучшая пригодность: 1.20939
# Поколение 461, Лучшая пригодность: 1.20939
# Поколение 462, Лучшая пригодность: 1.20939
# Поколение 463, Лучшая пригодность: 1.20939
# Поколение 464, Лучшая пригодность: 1.20939
# Поколение 465, Лучшая пригодность: 1.20939
# Поколение 466, Лучшая пригодность: 1.20939
# Поколение 467, Лучшая пригодность: 1.20939
# Поколение 468, Лучшая пригодность: 1.20939
# Поколение 469, Лучшая пригодность: 1.20939
# Поколение 470, Лучшая пригодность: 1.20939
# Поколение 471, Лучшая пригодность: 1.20939
# Поколение 472, Лучшая пригодность: 1.20939
# Поколение 473, Лучшая пригодность: 1.20939
# Поколение 474, Лучшая пригодность: 1.20939
# Поколение 475, Лучшая пригодность: 1.20939
# Поколение 476, Лучшая пригодность: 1.20939
# Поколение 477, Лучшая пригодность: 1.20939
# Поколение 478, Лучшая пригодность: 1.20939
# Поколение 479, Лучшая пригодность: 1.20939
# Поколение 480, Лучшая пригодность: 1.20939
# Поколение 481, Лучшая пригодность: 1.20939
# Поколение 482, Лучшая пригодность: 1.20939
# Поколение 483, Лучшая пригодность: 1.20939
# Поколение 484, Лучшая пригодность: 1.20939
# Поколение 485, Лучшая пригодность: 1.20939
# Поколение 486, Лучшая пригодность: 1.20939
# Поколение 487, Лучшая пригодность: 1.20939
# Поколение 488, Лучшая пригодность: 1.20939
# Поколение 489, Лучшая пригодность: 1.20939
# Поколение 490, Лучшая пригодность: 1.20939
# Поколение 491, Лучшая пригодность: 1.20939
# Поколение 492, Лучшая пригодность: 1.20939
# Поколение 493, Лучшая пригодность: 1.20939
# Поколение 494, Лучшая пригодность: 1.20939
# Поколение 495, Лучшая пригодность: 1.20939
# Поколение 496, Лучшая пригодность: 1.20939
# Поколение 497, Лучшая пригодность: 1.20939
# Поколение 498, Лучшая пригодность: 1.20939
# Поколение 499, Лучшая пригодность: 1.20939
# Поколение 500, Лучшая пригодность: 1.15075
# Поколение 501, Лучшая пригодность: 1.15075
# Поколение 502, Лучшая пригодность: 1.15075
# Поколение 503, Лучшая пригодность: 1.15075
# Поколение 504, Лучшая пригодность: 1.15075
# Поколение 505, Лучшая пригодность: 1.15075
# Поколение 506, Лучшая пригодность: 1.15075
# Поколение 507, Лучшая пригодность: 1.15075
# Поколение 508, Лучшая пригодность: 1.15075
# Поколение 509, Лучшая пригодность: 1.15075
# Поколение 510, Лучшая пригодность: 1.15075
# Поколение 511, Лучшая пригодность: 1.15075
# Поколение 512, Лучшая пригодность: 1.15075
# Поколение 513, Лучшая пригодность: 1.15075
# Поколение 514, Лучшая пригодность: 1.15075
# Поколение 515, Лучшая пригодность: 1.15075
# Поколение 516, Лучшая пригодность: 1.15075
# Поколение 517, Лучшая пригодность: 1.15075
# Поколение 518, Лучшая пригодность: 1.15075
# Поколение 519, Лучшая пригодность: 1.15075
# Поколение 520, Лучшая пригодность: 1.15075
# Поколение 521, Лучшая пригодность: 1.10675
# Поколение 522, Лучшая пригодность: 1.10675
# Поколение 523, Лучшая пригодность: 1.10675
# Поколение 524, Лучшая пригодность: 1.10675
# Поколение 525, Лучшая пригодность: 1.10392
# Поколение 526, Лучшая пригодность: 1.10392
# Поколение 527, Лучшая пригодность: 1.0981
# Поколение 528, Лучшая пригодность: 1.04754
# Поколение 529, Лучшая пригодность: 1.04754
# Поколение 530, Лучшая пригодность: 1.04754
# Поколение 531, Лучшая пригодность: 1.04754
# Поколение 532, Лучшая пригодность: 1.04754
# Поколение 533, Лучшая пригодность: 1.04754
# Поколение 534, Лучшая пригодность: 1.04754
# Поколение 535, Лучшая пригодность: 1.04754
# Поколение 536, Лучшая пригодность: 1.04754
# Поколение 537, Лучшая пригодность: 1.04754
# Поколение 538, Лучшая пригодность: 1.04754
# Поколение 539, Лучшая пригодность: 1.04754
# Поколение 540, Лучшая пригодность: 1.04754
# Поколение 541, Лучшая пригодность: 1.04754
# Поколение 542, Лучшая пригодность: 1.04754
# Поколение 543, Лучшая пригодность: 1.04754
# Поколение 544, Лучшая пригодность: 1.04754
# Поколение 545, Лучшая пригодность: 1.04754
# Поколение 546, Лучшая пригодность: 1.04754
# Поколение 547, Лучшая пригодность: 1.03504
# Поколение 548, Лучшая пригодность: 1.03246
# Поколение 549, Лучшая пригодность: 1.01601
# Поколение 550, Лучшая пригодность: 1.01601
# Поколение 551, Лучшая пригодность: 1.01601
# Поколение 552, Лучшая пригодность: 1.01427
# Поколение 553, Лучшая пригодность: 1.00643
# Поколение 554, Лучшая пригодность: 0.973933
# Поколение 555, Лучшая пригодность: 0.946542
# Поколение 556, Лучшая пригодность: 0.946542
# Поколение 557, Лучшая пригодность: 0.946542
# Поколение 558, Лучшая пригодность: 0.946411
# Поколение 559, Лучшая пригодность: 0.936307
# Поколение 560, Лучшая пригодность: 0.936307
# Поколение 561, Лучшая пригодность: 0.936307
# Поколение 562, Лучшая пригодность: 0.936307
# Поколение 563, Лучшая пригодность: 0.935502
# Поколение 564, Лучшая пригодность: 0.935499
# Поколение 565, Лучшая пригодность: 0.935371
# Поколение 566, Лучшая пригодность: 0.933867
# Поколение 567, Лучшая пригодность: 0.933867
# Поколение 568, Лучшая пригодность: 0.933867
# Поколение 569, Лучшая пригодность: 0.933867
# Поколение 570, Лучшая пригодность: 0.933359
# Поколение 571, Лучшая пригодность: 0.933228
# Поколение 572, Лучшая пригодность: 0.933228
# Поколение 573, Лучшая пригодность: 0.933228
# Поколение 574, Лучшая пригодность: 0.933221
# Поколение 575, Лучшая пригодность: 0.933221
# Поколение 576, Лучшая пригодность: 0.933221
# Поколение 577, Лучшая пригодность: 0.933221
# Поколение 578, Лучшая пригодность: 0.933221
# Поколение 579, Лучшая пригодность: 0.933221
# Поколение 580, Лучшая пригодность: 0.933221
# Поколение 581, Лучшая пригодность: 0.933221
# Поколение 582, Лучшая пригодность: 0.933221
# Поколение 583, Лучшая пригодность: 0.933221
# Поколение 584, Лучшая пригодность: 0.933221
# Поколение 585, Лучшая пригодность: 0.933221
# Поколение 586, Лучшая пригодность: 0.933218
# Поколение 587, Лучшая пригодность: 0.933218
# Поколение 588, Лучшая пригодность: 0.933218
# Поколение 589, Лучшая пригодность: 0.933218
# Поколение 590, Лучшая пригодность: 0.933218
# Поколение 591, Лучшая пригодность: 0.933218
# Поколение 592, Лучшая пригодность: 0.933218
# Поколение 593, Лучшая пригодность: 0.933218
# Поколение 594, Лучшая пригодность: 0.933218
# Поколение 595, Лучшая пригодность: 0.933218
# Поколение 596, Лучшая пригодность: 0.933218
# Поколение 597, Лучшая пригодность: 0.933218
# Поколение 598, Лучшая пригодность: 0.933218
# Поколение 599, Лучшая пригодность: 0.933218
# Поколение 600, Лучшая пригодность: 0.933218
# Поколение 601, Лучшая пригодность: 0.933218
# Поколение 602, Лучшая пригодность: 0.933218
# Поколение 603, Лучшая пригодность: 0.933218
# Поколение 604, Лучшая пригодность: 0.933218
# Поколение 605, Лучшая пригодность: 0.933218
# Поколение 606, Лучшая пригодность: 0.933218
# Поколение 607, Лучшая пригодность: 0.933218
# Поколение 608, Лучшая пригодность: 0.933218
# Поколение 609, Лучшая пригодность: 0.933218
# Поколение 610, Лучшая пригодность: 0.933218
# Поколение 611, Лучшая пригодность: 0.933218
# Поколение 612, Лучшая пригодность: 0.933218
# Поколение 613, Лучшая пригодность: 0.933218
# Поколение 614, Лучшая пригодность: 0.920311
# Поколение 615, Лучшая пригодность: 0.920311
# Поколение 616, Лучшая пригодность: 0.920311
# Поколение 617, Лучшая пригодность: 0.920311
# Поколение 618, Лучшая пригодность: 0.920311
# Поколение 619, Лучшая пригодность: 0.920311
# Поколение 620, Лучшая пригодность: 0.920311
# Поколение 621, Лучшая пригодность: 0.920311
# Поколение 622, Лучшая пригодность: 0.920311
# Поколение 623, Лучшая пригодность: 0.920311
# Поколение 624, Лучшая пригодность: 0.920311
# Поколение 625, Лучшая пригодность: 0.920311
# Поколение 626, Лучшая пригодность: 0.920311
# Поколение 627, Лучшая пригодность: 0.920311
# Поколение 628, Лучшая пригодность: 0.920311
# Поколение 629, Лучшая пригодность: 0.920311
# Поколение 630, Лучшая пригодность: 0.920311
# Поколение 631, Лучшая пригодность: 0.920311
# Поколение 632, Лучшая пригодность: 0.920311
# Поколение 633, Лучшая пригодность: 0.920311
# Поколение 634, Лучшая пригодность: 0.920311
# Поколение 635, Лучшая пригодность: 0.920311
# Поколение 636, Лучшая пригодность: 0.920311
# Поколение 637, Лучшая пригодность: 0.920311
# Поколение 638, Лучшая пригодность: 0.920311
# Поколение 639, Лучшая пригодность: 0.920311
# Поколение 640, Лучшая пригодность: 0.920311
# Поколение 641, Лучшая пригодность: 0.920311
# Поколение 642, Лучшая пригодность: 0.920311
# Поколение 643, Лучшая пригодность: 0.918693
# Поколение 644, Лучшая пригодность: 0.918693
# Поколение 645, Лучшая пригодность: 0.918693
# Поколение 646, Лучшая пригодность: 0.918693
# Поколение 647, Лучшая пригодность: 0.918693
# Поколение 648, Лучшая пригодность: 0.918693
# Поколение 649, Лучшая пригодность: 0.918693
# Поколение 650, Лучшая пригодность: 0.918693
# Поколение 651, Лучшая пригодность: 0.918189
# Поколение 652, Лучшая пригодность: 0.917049
# Поколение 653, Лучшая пригодность: 0.917049
# Поколение 654, Лучшая пригодность: 0.917049
# Поколение 655, Лучшая пригодность: 0.917049
# Поколение 656, Лучшая пригодность: 0.917049
# Поколение 657, Лучшая пригодность: 0.917049
# Поколение 658, Лучшая пригодность: 0.917049
# Поколение 659, Лучшая пригодность: 0.917049
# Поколение 660, Лучшая пригодность: 0.917049
# Поколение 661, Лучшая пригодность: 0.917046
# Поколение 662, Лучшая пригодность: 0.917046
# Поколение 663, Лучшая пригодность: 0.862327
# Поколение 664, Лучшая пригодность: 0.862327
# Поколение 665, Лучшая пригодность: 0.862327
# Поколение 666, Лучшая пригодность: 0.862327
# Поколение 667, Лучшая пригодность: 0.862327
# Поколение 668, Лучшая пригодность: 0.862327
# Поколение 669, Лучшая пригодность: 0.862327
# Поколение 670, Лучшая пригодность: 0.862327
# Поколение 671, Лучшая пригодность: 0.817093
# Поколение 672, Лучшая пригодность: 0.817093
# Поколение 673, Лучшая пригодность: 0.817039
# Поколение 674, Лучшая пригодность: 0.805191
# Поколение 675, Лучшая пригодность: 0.805191
# Поколение 676, Лучшая пригодность: 0.803267
# Поколение 677, Лучшая пригодность: 0.798028
# Поколение 678, Лучшая пригодность: 0.798028
# Поколение 679, Лучшая пригодность: 0.798028
# Поколение 680, Лучшая пригодность: 0.798028
# Поколение 681, Лучшая пригодность: 0.798028
# Поколение 682, Лучшая пригодность: 0.798028
# Поколение 683, Лучшая пригодность: 0.798028
# Поколение 684, Лучшая пригодность: 0.798028
# Поколение 685, Лучшая пригодность: 0.798028
# Поколение 686, Лучшая пригодность: 0.797026
# Поколение 687, Лучшая пригодность: 0.797026
# Поколение 688, Лучшая пригодность: 0.797026
# Поколение 689, Лучшая пригодность: 0.797026
# Поколение 690, Лучшая пригодность: 0.797026
# Поколение 691, Лучшая пригодность: 0.797026
# Поколение 692, Лучшая пригодность: 0.797026
# Поколение 693, Лучшая пригодность: 0.797026
# Поколение 694, Лучшая пригодность: 0.797026
# Поколение 695, Лучшая пригодность: 0.797026
# Поколение 696, Лучшая пригодность: 0.797026
# Поколение 697, Лучшая пригодность: 0.797026
# Поколение 698, Лучшая пригодность: 0.797026
# Поколение 699, Лучшая пригодность: 0.797026
# Поколение 700, Лучшая пригодность: 0.797026
# Поколение 701, Лучшая пригодность: 0.797026
# Поколение 702, Лучшая пригодность: 0.797026
# Поколение 703, Лучшая пригодность: 0.796305
# Поколение 704, Лучшая пригодность: 0.796267
# Поколение 705, Лучшая пригодность: 0.796236
# Поколение 706, Лучшая пригодность: 0.796218
# Поколение 707, Лучшая пригодность: 0.796218
# Поколение 708, Лучшая пригодность: 0.795755
# Поколение 709, Лучшая пригодность: 0.795755
# Поколение 710, Лучшая пригодность: 0.795755
# Поколение 711, Лучшая пригодность: 0.795755
# Поколение 712, Лучшая пригодность: 0.795755
# Поколение 713, Лучшая пригодность: 0.795737
# Поколение 714, Лучшая пригодность: 0.795736
# Поколение 715, Лучшая пригодность: 0.795736
# Поколение 716, Лучшая пригодность: 0.77874
# Поколение 717, Лучшая пригодность: 0.778681
# Поколение 718, Лучшая пригодность: 0.778681
# Поколение 719, Лучшая пригодность: 0.778681
# Поколение 720, Лучшая пригодность: 0.778681
# Поколение 721, Лучшая пригодность: 0.778681
# Поколение 722, Лучшая пригодность: 0.778681
# Поколение 723, Лучшая пригодность: 0.778681
# Поколение 724, Лучшая пригодность: 0.759663
# Поколение 725, Лучшая пригодность: 0.759663
# Поколение 726, Лучшая пригодность: 0.759663
# Поколение 727, Лучшая пригодность: 0.759663
# Поколение 728, Лучшая пригодность: 0.740444
# Поколение 729, Лучшая пригодность: 0.740444
# Поколение 730, Лучшая пригодность: 0.740444
# Поколение 731, Лучшая пригодность: 0.740444
# Поколение 732, Лучшая пригодность: 0.738628
# Поколение 733, Лучшая пригодность: 0.738628
# Поколение 734, Лучшая пригодность: 0.717658
# Поколение 735, Лучшая пригодность: 0.708517
# Поколение 736, Лучшая пригодность: 0.703646
# Поколение 737, Лучшая пригодность: 0.702791
# Поколение 738, Лучшая пригодность: 0.702791
# Поколение 739, Лучшая пригодность: 0.702791
# Поколение 740, Лучшая пригодность: 0.702791
# Поколение 741, Лучшая пригодность: 0.702791
# Поколение 742, Лучшая пригодность: 0.702791
# Поколение 743, Лучшая пригодность: 0.702791
# Поколение 744, Лучшая пригодность: 0.700684
# Поколение 745, Лучшая пригодность: 0.700684
# Поколение 746, Лучшая пригодность: 0.700684
# Поколение 747, Лучшая пригодность: 0.700684
# Поколение 748, Лучшая пригодность: 0.700684
# Поколение 749, Лучшая пригодность: 0.700684
# Поколение 750, Лучшая пригодность: 0.700684
# Поколение 751, Лучшая пригодность: 0.700684
# Поколение 752, Лучшая пригодность: 0.700683
# Поколение 753, Лучшая пригодность: 0.700681
# Поколение 754, Лучшая пригодность: 0.700676
# Поколение 755, Лучшая пригодность: 0.700266
# Поколение 756, Лучшая пригодность: 0.700266
# Поколение 757, Лучшая пригодность: 0.700266
# Поколение 758, Лучшая пригодность: 0.695487
# Поколение 759, Лучшая пригодность: 0.687096
# Поколение 760, Лучшая пригодность: 0.687096
# Поколение 761, Лучшая пригодность: 0.687096
# Поколение 762, Лучшая пригодность: 0.687096
# Поколение 763, Лучшая пригодность: 0.687096
# Поколение 764, Лучшая пригодность: 0.687096
# Поколение 765, Лучшая пригодность: 0.687096
# Поколение 766, Лучшая пригодность: 0.687096
# Поколение 767, Лучшая пригодность: 0.669259
# Поколение 768, Лучшая пригодность: 0.660179
# Поколение 769, Лучшая пригодность: 0.654984
# Поколение 770, Лучшая пригодность: 0.621624
# Поколение 771, Лучшая пригодность: 0.58382
# Поколение 772, Лучшая пригодность: 0.581363
# Поколение 773, Лучшая пригодность: 0.581363
# Поколение 774, Лучшая пригодность: 0.581363
# Поколение 775, Лучшая пригодность: 0.581363
# Поколение 776, Лучшая пригодность: 0.581363
# Поколение 777, Лучшая пригодность: 0.581363
# Поколение 778, Лучшая пригодность: 0.581363
# Поколение 779, Лучшая пригодность: 0.581363
# Поколение 780, Лучшая пригодность: 0.576436
# Поколение 781, Лучшая пригодность: 0.576436
# Поколение 782, Лучшая пригодность: 0.576436
# Поколение 783, Лучшая пригодность: 0.576246
# Поколение 784, Лучшая пригодность: 0.576246
# Поколение 785, Лучшая пригодность: 0.576246
# Поколение 786, Лучшая пригодность: 0.576246
# Поколение 787, Лучшая пригодность: 0.576246
# Поколение 788, Лучшая пригодность: 0.576211
# Поколение 789, Лучшая пригодность: 0.576211
# Поколение 790, Лучшая пригодность: 0.576211
# Поколение 791, Лучшая пригодность: 0.576211
# Поколение 792, Лучшая пригодность: 0.569362
# Поколение 793, Лучшая пригодность: 0.569362
# Поколение 794, Лучшая пригодность: 0.557653
# Поколение 795, Лучшая пригодность: 0.55704
# Поколение 796, Лучшая пригодность: 0.551321
# Поколение 797, Лучшая пригодность: 0.551097
# Поколение 798, Лучшая пригодность: 0.551097
# Поколение 799, Лучшая пригодность: 0.551097
# Поколение 800, Лучшая пригодность: 0.551087
# Поколение 801, Лучшая пригодность: 0.551087
# Поколение 802, Лучшая пригодность: 0.54559
# Поколение 803, Лучшая пригодность: 0.54559
# Поколение 804, Лучшая пригодность: 0.54559
# Поколение 805, Лучшая пригодность: 0.54559
# Поколение 806, Лучшая пригодность: 0.545589
# Поколение 807, Лучшая пригодность: 0.545589
# Поколение 808, Лучшая пригодность: 0.545589
# Поколение 809, Лучшая пригодность: 0.545589
# Поколение 810, Лучшая пригодность: 0.545589
# Поколение 811, Лучшая пригодность: 0.545589
# Поколение 812, Лучшая пригодность: 0.543246
# Поколение 813, Лучшая пригодность: 0.543087
# Поколение 814, Лучшая пригодность: 0.528813
# Поколение 815, Лучшая пригодность: 0.528813
# Поколение 816, Лучшая пригодность: 0.528812
# Поколение 817, Лучшая пригодность: 0.528812
# Поколение 818, Лучшая пригодность: 0.524872
# Поколение 819, Лучшая пригодность: 0.524872
# Поколение 820, Лучшая пригодность: 0.524872
# Поколение 821, Лучшая пригодность: 0.524872
# Поколение 822, Лучшая пригодность: 0.515113
# Поколение 823, Лучшая пригодность: 0.480962
# Поколение 824, Лучшая пригодность: 0.477442
# Поколение 825, Лучшая пригодность: 0.445932
# Поколение 826, Лучшая пригодность: 0.445931
# Поколение 827, Лучшая пригодность: 0.445931
# Поколение 828, Лучшая пригодность: 0.445931
# Поколение 829, Лучшая пригодность: 0.445931
# Поколение 830, Лучшая пригодность: 0.445931
# Поколение 831, Лучшая пригодность: 0.445931
# Поколение 832, Лучшая пригодность: 0.445236
# Поколение 833, Лучшая пригодность: 0.445236
# Поколение 834, Лучшая пригодность: 0.445236
# Поколение 835, Лучшая пригодность: 0.44324
# Поколение 836, Лучшая пригодность: 0.44324
# Поколение 837, Лучшая пригодность: 0.44324
# Поколение 838, Лучшая пригодность: 0.44324
# Поколение 839, Лучшая пригодность: 0.44324
# Поколение 840, Лучшая пригодность: 0.44324
# Поколение 841, Лучшая пригодность: 0.44324
# Поколение 842, Лучшая пригодность: 0.44324
# Поколение 843, Лучшая пригодность: 0.44324
# Поколение 844, Лучшая пригодность: 0.44324
# Поколение 845, Лучшая пригодность: 0.44324
# Поколение 846, Лучшая пригодность: 0.44324
# Поколение 847, Лучшая пригодность: 0.44324
# Поколение 848, Лучшая пригодность: 0.44324
# Поколение 849, Лучшая пригодность: 0.436755
# Поколение 850, Лучшая пригодность: 0.436755
# Поколение 851, Лучшая пригодность: 0.43199
# Поколение 852, Лучшая пригодность: 0.431658
# Поколение 853, Лучшая пригодность: 0.431658
# Поколение 854, Лучшая пригодность: 0.421927
# Поколение 855, Лучшая пригодность: 0.421927
# Поколение 856, Лучшая пригодность: 0.421738
# Поколение 857, Лучшая пригодность: 0.421483
# Поколение 858, Лучшая пригодность: 0.408933
# Поколение 859, Лучшая пригодность: 0.406381
# Поколение 860, Лучшая пригодность: 0.406084
# Поколение 861, Лучшая пригодность: 0.406084
# Поколение 862, Лучшая пригодность: 0.406084
# Поколение 863, Лучшая пригодность: 0.406015
# Поколение 864, Лучшая пригодность: 0.404837
# Поколение 865, Лучшая пригодность: 0.404198
# Поколение 866, Лучшая пригодность: 0.404198
# Поколение 867, Лучшая пригодность: 0.403785
# Поколение 868, Лучшая пригодность: 0.403784
# Поколение 869, Лучшая пригодность: 0.403784
# Поколение 870, Лучшая пригодность: 0.403784
# Поколение 871, Лучшая пригодность: 0.403784
# Поколение 872, Лучшая пригодность: 0.402964
# Поколение 873, Лучшая пригодность: 0.402495
# Поколение 874, Лучшая пригодность: 0.402495
# Поколение 875, Лучшая пригодность: 0.402495
# Поколение 876, Лучшая пригодность: 0.402495
# Поколение 877, Лучшая пригодность: 0.402495
# Поколение 878, Лучшая пригодность: 0.402495
# Поколение 879, Лучшая пригодность: 0.402495
# Поколение 880, Лучшая пригодность: 0.402495
# Поколение 881, Лучшая пригодность: 0.402495
# Поколение 882, Лучшая пригодность: 0.402491
# Поколение 883, Лучшая пригодность: 0.402491
# Поколение 884, Лучшая пригодность: 0.402491
# Поколение 885, Лучшая пригодность: 0.402481
# Поколение 886, Лучшая пригодность: 0.402481
# Поколение 887, Лучшая пригодность: 0.402481
# Поколение 888, Лучшая пригодность: 0.401906
# Поколение 889, Лучшая пригодность: 0.401906
# Поколение 890, Лучшая пригодность: 0.401837
# Поколение 891, Лучшая пригодность: 0.401837
# Поколение 892, Лучшая пригодность: 0.401837
# Поколение 893, Лучшая пригодность: 0.390133
# Поколение 894, Лучшая пригодность: 0.390132
# Поколение 895, Лучшая пригодность: 0.389157
# Поколение 896, Лучшая пригодность: 0.385016
# Поколение 897, Лучшая пригодность: 0.385002
# Поколение 898, Лучшая пригодность: 0.385002
# Поколение 899, Лучшая пригодность: 0.379734
# Поколение 900, Лучшая пригодность: 0.379734
# Поколение 901, Лучшая пригодность: 0.379734
# Поколение 902, Лучшая пригодность: 0.379734
# Поколение 903, Лучшая пригодность: 0.379734
# Поколение 904, Лучшая пригодность: 0.379734
# Поколение 905, Лучшая пригодность: 0.379631
# Поколение 906, Лучшая пригодность: 0.379066
# Поколение 907, Лучшая пригодность: 0.3625
# Поколение 908, Лучшая пригодность: 0.3625
# Поколение 909, Лучшая пригодность: 0.362463
# Поколение 910, Лучшая пригодность: 0.362463
# Поколение 911, Лучшая пригодность: 0.356616
# Поколение 912, Лучшая пригодность: 0.356616
# Поколение 913, Лучшая пригодность: 0.356616
# Поколение 914, Лучшая пригодность: 0.354949
# Поколение 915, Лучшая пригодность: 0.354949
# Поколение 916, Лучшая пригодность: 0.354949
# Поколение 917, Лучшая пригодность: 0.332354
# Поколение 918, Лучшая пригодность: 0.332354
# Поколение 919, Лучшая пригодность: 0.332354
# Поколение 920, Лучшая пригодность: 0.332354
# Поколение 921, Лучшая пригодность: 0.332354
# Поколение 922, Лучшая пригодность: 0.332354
# Поколение 923, Лучшая пригодность: 0.332354
# Поколение 924, Лучшая пригодность: 0.332354
# Поколение 925, Лучшая пригодность: 0.331191
# Поколение 926, Лучшая пригодность: 0.331191
# Поколение 927, Лучшая пригодность: 0.331191
# Поколение 928, Лучшая пригодность: 0.331191
# Поколение 929, Лучшая пригодность: 0.331185
# Поколение 930, Лучшая пригодность: 0.331185
# Поколение 931, Лучшая пригодность: 0.331185
# Поколение 932, Лучшая пригодность: 0.331185
# Поколение 933, Лучшая пригодность: 0.331185
# Поколение 934, Лучшая пригодность: 0.331185
# Поколение 935, Лучшая пригодность: 0.331185
# Поколение 936, Лучшая пригодность: 0.330918
# Поколение 937, Лучшая пригодность: 0.330394
# Поколение 938, Лучшая пригодность: 0.330394
# Поколение 939, Лучшая пригодность: 0.330394
# Поколение 940, Лучшая пригодность: 0.330394
# Поколение 941, Лучшая пригодность: 0.329686
# Поколение 942, Лучшая пригодность: 0.329686
# Поколение 943, Лучшая пригодность: 0.324891
# Поколение 944, Лучшая пригодность: 0.324891
# Поколение 945, Лучшая пригодность: 0.324891
# Поколение 946, Лучшая пригодность: 0.324891
# Поколение 947, Лучшая пригодность: 0.322889
# Поколение 948, Лучшая пригодность: 0.322889
# Поколение 949, Лучшая пригодность: 0.322889
# Поколение 950, Лучшая пригодность: 0.322889
# Поколение 951, Лучшая пригодность: 0.322889
# Поколение 952, Лучшая пригодность: 0.322889
# Поколение 953, Лучшая пригодность: 0.322889
# Поколение 954, Лучшая пригодность: 0.322889
# Поколение 955, Лучшая пригодность: 0.322889
# Поколение 956, Лучшая пригодность: 0.322889
# Поколение 957, Лучшая пригодность: 0.322889
# Поколение 958, Лучшая пригодность: 0.322889
# Поколение 959, Лучшая пригодность: 0.322889
# Поколение 960, Лучшая пригодность: 0.322889
# Поколение 961, Лучшая пригодность: 0.322889
# Поколение 962, Лучшая пригодность: 0.322889
# Поколение 963, Лучшая пригодность: 0.322889
# Поколение 964, Лучшая пригодность: 0.322889
# Поколение 965, Лучшая пригодность: 0.322889
# Поколение 966, Лучшая пригодность: 0.322889
# Поколение 967, Лучшая пригодность: 0.322889
# Поколение 968, Лучшая пригодность: 0.322889
# Поколение 969, Лучшая пригодность: 0.322889
# Поколение 970, Лучшая пригодность: 0.316646
# Поколение 971, Лучшая пригодность: 0.316646
# Поколение 972, Лучшая пригодность: 0.316646
# Поколение 973, Лучшая пригодность: 0.316646
# Поколение 974, Лучшая пригодность: 0.316646
# Поколение 975, Лучшая пригодность: 0.316646
# Поколение 976, Лучшая пригодность: 0.316646
# Поколение 977, Лучшая пригодность: 0.316646
# Поколение 978, Лучшая пригодность: 0.315451
# Поколение 979, Лучшая пригодность: 0.315451
# Поколение 980, Лучшая пригодность: 0.315451
# Поколение 981, Лучшая пригодность: 0.315451
# Поколение 982, Лучшая пригодность: 0.315451
# Поколение 983, Лучшая пригодность: 0.315451
# Поколение 984, Лучшая пригодность: 0.315409
# Поколение 985, Лучшая пригодность: 0.313637
# Поколение 986, Лучшая пригодность: 0.313637
# Поколение 987, Лучшая пригодность: 0.313637
# Поколение 988, Лучшая пригодность: 0.313637
# Поколение 989, Лучшая пригодность: 0.313637
# Поколение 990, Лучшая пригодность: 0.313637
# Поколение 991, Лучшая пригодность: 0.313637
# Поколение 992, Лучшая пригодность: 0.313637
# Поколение 993, Лучшая пригодность: 0.313637
# Поколение 994, Лучшая пригодность: 0.313637
# Поколение 995, Лучшая пригодность: 0.313139
# Поколение 996, Лучшая пригодность: 0.313139
# Поколение 997, Лучшая пригодность: 0.313139
# Поколение 998, Лучшая пригодность: 0.313139
# Поколение 999, Лучшая пригодность: 0.313139
# Заданные коэффициенты: 2.77663 -0.606292 -3.0323 3.34414 -1.47458
# Лучшие коэффициенты полинома: 2.08489 -0.577274 -2.78322 3.34273 -1.48583
